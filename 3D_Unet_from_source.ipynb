# %% [markdown]
# <a href="https://colab.research.google.com/github/RichardHarwood/3D-Cell-Workflow/blob/main/3D_Unet_from_source.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Note that 3D_Unet uses H5 Data to convert 3DTIFF (most likely format ) you need to run the following:
#
#
# ```
# from skimage import io
# import h5py
#
# img=skimage.io.imread("path to raw tif")
# mask=skimage.io.imread("path to mask tif")
#
# hf = h5py.File("path to new .h5 file", 'w')
# hf.create_dataset('raw', data=img)
# hf.create_dataset('label', data=mask)
# hf.close()
# ```
#
# #Note that "raw" and "label" correspond to the config files used to train the model and segment data

# %%
#Note that 3D_Unet uses H5 Data to convert 3DTIFF (most likely format )
# Out:
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (3.2)
# Requirement already satisfied: open3d in /usr/local/lib/python3.10/dist-packages (0.18.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from open3d) (1.26.4)
# Requirement already satisfied: dash>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from open3d) (2.18.1)
# Requirement already satisfied: werkzeug>=2.2.3 in /usr/local/lib/python3.10/dist-packages (from open3d) (3.0.4)
# Requirement already satisfied: nbformat>=5.7.0 in /usr/local/lib/python3.10/dist-packages (from open3d) (5.10.4)
# Requirement already satisfied: configargparse in /usr/local/lib/python3.10/dist-packages (from open3d) (1.7)
# Requirement already satisfied: ipywidgets>=8.0.4 in /usr/local/lib/python3.10/dist-packages (from open3d) (8.1.5)
# Requirement already satisfied: addict in /usr/local/lib/python3.10/dist-packages (from open3d) (2.4.0)
# Requirement already satisfied: pillow>=9.3.0 in /usr/local/lib/python3.10/dist-packages (from open3d) (10.4.0)
# Requirement already satisfied: matplotlib>=3 in /usr/local/lib/python3.10/dist-packages (from open3d) (3.7.1)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from open3d) (2.2.2)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from open3d) (6.0.2)
# Requirement already satisfied: scikit-learn>=0.21 in /usr/local/lib/python3.10/dist-packages (from open3d) (1.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from open3d) (4.66.5)
# Requirement already satisfied: pyquaternion in /usr/local/lib/python3.10/dist-packages (from open3d) (0.9.9)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (2.2.5)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (5.24.1)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (5.0.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (4.12.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (2.32.3)
# Requirement already satisfied: retrying in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (1.3.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from dash>=2.6.0->open3d) (71.0.4)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0.4->open3d) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0.4->open3d) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0.4->open3d) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0.4->open3d) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0.4->open3d) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->open3d) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->open3d) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->open3d) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->open3d) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->open3d) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->open3d) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->open3d) (2.8.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.7.0->open3d) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.7.0->open3d) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.7.0->open3d) (5.7.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->open3d) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->open3d) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21->open3d) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21->open3d) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21->open3d) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=2.2.3->open3d) (3.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (2.2.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash>=2.6.0->open3d) (8.1.7)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (4.3.6)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (9.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3->open3d) (1.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->dash>=2.6.0->open3d) (3.20.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dash>=2.6.0->open3d) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dash>=2.6.0->open3d) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dash>=2.6.0->open3d) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dash>=2.6.0->open3d) (2024.8.30)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.13)
# Requirement already satisfied: vedo in /usr/local/lib/python3.10/dist-packages (2024.5.2)
# Requirement already satisfied: vtk in /usr/local/lib/python3.10/dist-packages (from vedo) (9.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vedo) (1.26.4)
# Requirement already satisfied: Pygments in /usr/local/lib/python3.10/dist-packages (from vedo) (2.18.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from vedo) (4.12.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from vtk->vedo) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk->vedo) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk->vedo) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk->vedo) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk->vedo) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk->vedo) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk->vedo) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk->vedo) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->vtk->vedo) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->vtk->vedo) (1.16.0)

# %%
# !pip install wget
# !pip install open3d
# !pip install vedo

# %%
import os
# !git clone https://github.com/wolny/pytorch-3dunet.git
# Out:
# fatal: destination path 'pytorch-3dunet' already exists and is not an empty directory.

# %%
  # %cd pytorch-3dunet
# Out:
# /content/pytorch-3dunet

# %%
# !python setup.py install
# Out:
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing pytorch3dunet.egg-info/PKG-INFO
# writing dependency_links to pytorch3dunet.egg-info/dependency_links.txt
# writing entry points to pytorch3dunet.egg-info/entry_points.txt
# writing top-level names to pytorch3dunet.egg-info/top_level.txt
# reading manifest file 'pytorch3dunet.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'pytorch3dunet.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying pytorch3dunet/__init__.py -> build/lib/pytorch3dunet
# copying pytorch3dunet/__version__.py -> build/lib/pytorch3dunet
# copying pytorch3dunet/predict.py -> build/lib/pytorch3dunet
# copying pytorch3dunet/train.py -> build/lib/pytorch3dunet
# copying pytorch3dunet/datasets/__init__.py -> build/lib/pytorch3dunet/datasets
# copying pytorch3dunet/datasets/utils.py -> build/lib/pytorch3dunet/datasets
# copying pytorch3dunet/datasets/hdf5.py -> build/lib/pytorch3dunet/datasets
# copying pytorch3dunet/datasets/dsb.py -> build/lib/pytorch3dunet/datasets
# copying pytorch3dunet/unet3d/metrics.py -> build/lib/pytorch3dunet/unet3d
# copying pytorch3dunet/unet3d/__init__.py -> build/lib/pytorch3dunet/unet3d
# copying pytorch3dunet/unet3d/utils.py -> build/lib/pytorch3dunet/unet3d
# copying pytorch3dunet/unet3d/predictor.py -> build/lib/pytorch3dunet/unet3d
# copying pytorch3dunet/unet3d/trainer.py -> build/lib/pytorch3dunet/unet3d
# copying pytorch3dunet/unet3d/se.py -> build/lib/pytorch3dunet/unet3d
# copying pytorch3dunet/unet3d/buildingblocks.py -> build/lib/pytorch3dunet/unet3d
# copying pytorch3dunet/unet3d/losses.py -> build/lib/pytorch3dunet/unet3d
# copying pytorch3dunet/unet3d/config.py -> build/lib/pytorch3dunet/unet3d
# copying pytorch3dunet/unet3d/seg_metrics.py -> build/lib/pytorch3dunet/unet3d
# copying pytorch3dunet/unet3d/model.py -> build/lib/pytorch3dunet/unet3d
# copying pytorch3dunet/augment/__init__.py -> build/lib/pytorch3dunet/augment
# copying pytorch3dunet/augment/transforms.py -> build/lib/pytorch3dunet/augment
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/pytorch3dunet
# creating build/bdist.linux-x86_64/egg/pytorch3dunet/datasets
# copying build/lib/pytorch3dunet/datasets/__init__.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/datasets
# copying build/lib/pytorch3dunet/datasets/utils.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/datasets
# copying build/lib/pytorch3dunet/datasets/hdf5.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/datasets
# copying build/lib/pytorch3dunet/datasets/dsb.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/datasets
# copying build/lib/pytorch3dunet/__init__.py -> build/bdist.linux-x86_64/egg/pytorch3dunet
# creating build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d
# copying build/lib/pytorch3dunet/unet3d/metrics.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d
# copying build/lib/pytorch3dunet/unet3d/__init__.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d
# copying build/lib/pytorch3dunet/unet3d/utils.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d
# copying build/lib/pytorch3dunet/unet3d/predictor.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d
# copying build/lib/pytorch3dunet/unet3d/trainer.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d
# copying build/lib/pytorch3dunet/unet3d/se.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d
# copying build/lib/pytorch3dunet/unet3d/buildingblocks.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d
# copying build/lib/pytorch3dunet/unet3d/losses.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d
# copying build/lib/pytorch3dunet/unet3d/config.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d
# copying build/lib/pytorch3dunet/unet3d/seg_metrics.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d
# copying build/lib/pytorch3dunet/unet3d/model.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d
# copying build/lib/pytorch3dunet/__version__.py -> build/bdist.linux-x86_64/egg/pytorch3dunet
# copying build/lib/pytorch3dunet/predict.py -> build/bdist.linux-x86_64/egg/pytorch3dunet
# creating build/bdist.linux-x86_64/egg/pytorch3dunet/augment
# copying build/lib/pytorch3dunet/augment/__init__.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/augment
# copying build/lib/pytorch3dunet/augment/transforms.py -> build/bdist.linux-x86_64/egg/pytorch3dunet/augment
# copying build/lib/pytorch3dunet/train.py -> build/bdist.linux-x86_64/egg/pytorch3dunet
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/datasets/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/datasets/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/datasets/hdf5.py to hdf5.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/datasets/dsb.py to dsb.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d/metrics.py to metrics.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d/predictor.py to predictor.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d/trainer.py to trainer.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d/se.py to se.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d/buildingblocks.py to buildingblocks.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d/losses.py to losses.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d/config.py to config.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d/seg_metrics.py to seg_metrics.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/unet3d/model.py to model.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/__version__.py to __version__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/predict.py to predict.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/augment/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/augment/transforms.py to transforms.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pytorch3dunet/train.py to train.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying pytorch3dunet.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pytorch3dunet.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pytorch3dunet.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pytorch3dunet.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pytorch3dunet.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/pytorch3dunet-1.8.7-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing pytorch3dunet-1.8.7-py3.10.egg
# Removing /usr/local/lib/python3.10/dist-packages/pytorch3dunet-1.8.7-py3.10.egg
# Copying pytorch3dunet-1.8.7-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding pytorch3dunet 1.8.7 to easy-install.pth file
# Installing predict3dunet script to /usr/local/bin
# Installing train3dunet script to /usr/local/bin
#
# Installed /usr/local/lib/python3.10/dist-packages/pytorch3dunet-1.8.7-py3.10.egg
# Processing dependencies for pytorch3dunet==1.8.7
# Finished processing dependencies for pytorch3dunet==1.8.7

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#need to set appropriate  home folder
import os.path
from os import path
if path.exists('/content/drive/MyDrive/3D_UNET/') == False:
  os.mkdir('/content/drive/MyDrive/3D_UNET/')
home_folder = "/content/drive/MyDrive/3D_UNET/"

# %%
#Create Config Folder

if path.exists(home_folder+'config_files') == False:
  os.mkdir(home_folder+'config_files')
config_folder = home_folder+'config_files/'

# %%
#Create Checkpoint Folder
if path.exists(home_folder+'checkpoint_dir') == False:
  os.mkdir(home_folder+'checkpoint_dir')
checkpoint_dir = home_folder+'checkpoint_dir/'

# %%
#Create Training_data Folder

if path.exists(home_folder+'training_data/train/') == False:
  os.mkdir(home_folder+'training_data/train/')

if path.exists(home_folder+'training_data/qc/') == False:
  os.mkdir(home_folder+'training_data/qc/')

if path.exists(home_folder+'training_data/test/') == False:
  os.mkdir(home_folder+'training_data/test/')

# %%
# !pip install wget
import wget

# %% [markdown]
# **Download example training data**

# %%
#!pip install wget
# import wget
# wget.download("https://zenodo.org/records/4766931/files/"+"E camaldulensis - Cropped.tif"+"?download=1", out='/content/drive/MyDrive/3D_UNET/download_data/euc.tif')

# %%
#Create folder to store zenodo data

# %% [markdown]
# Choose all the settings here

# %%
model_name = "UNet3D"
in_channels = 1
out_channels= 1
layer_order = "gcr"
f_maps = [32,
          64,
          128,
          256]
num_groups = 8
final_sigmoid = True
is_segmentation = True
resume = None
pre_trained = None
validate_after_iters = 500
log_after_iters = 500
max_num_epochs = 10  ##Low for testing
max_num_iterations = 1800000
eval_score_higher_is_better = True
loss_name= 'BCEWithLogitsLoss'
learning_rate= 0.0002
weight_decay= 0.00001
eval_name= "MeanIoU"
lr_name= "ReduceLROnPlateau"
mode= 'max'
factor = 0.2
patience = 30
dataset= "StandardHDF5Dataset"
batch_size= 3  #important for gpu memory
num_workers= 2
raw_internal_path= "raw"
label_internal_path= "label"
weight_internal_path= None
################3
file_paths_train= home_folder+'training_data/train/'
######################
slice_builder_name= "SliceBuilder"
slice_builder_name_predict = "SliceBuilder"
patch_shape= [40, 170, 170]  #Change depending on GPU memory
stride_shape= [20, 40, 40]   #Change depending on GPU memory
halo_shape= [16, 32, 32]
threshold = 0.01
slack_acceptance = 0.01
name_transformer= "Standardize"
name_transformer_label= "BlobsToMask"
append_label= False
boundary= False
ToTensor_name = "ToTensor"
expand_dims_false= False
expand_dims_true= True
################
file_paths_val= home_folder+'training_data/qc/'
#####################
predictor_name='StandardPredictor'
#################################
file_paths_test= home_folder+'training_data/test/'
#############################
model_path=checkpoint_dir+"best_checkpoint.pytorch"

# %% [markdown]
# Code below creates .yaml file

# %%
# @title
#https://stackoverflow.com/questions/12470665/how-can-i-write-data-in-yaml-format-in-a-file
#https://stackoverflow.com/questions/59034564/yaml-dump-seeming-to-add-two-dashes-to-2nd-row-under-first-key


import yaml
train_intrem_config = {'model':{'name':model_name,
                                'in_channels':in_channels,
                                'out_channels':out_channels,
                                'layer_order':layer_order,
                                'f_maps':f_maps,
                                'num_groups':num_groups,
                                'final_sigmoid':final_sigmoid,
                                'is_segmentation':is_segmentation},
                       'trainer': {'checkpoint_dir':checkpoint_dir,
                                   'resume':resume,
                                   'pre_trained':pre_trained,
                                   'validate_after_iters':validate_after_iters,
                                   'log_after_iters':log_after_iters,
                                   'max_num_epochs':max_num_epochs,
                                   'max_num_iterations':max_num_iterations,
                                   'eval_score_higher_is_better':eval_score_higher_is_better},
                       'loss':{'name':loss_name},
                       'optimizer':{'learning_rate':learning_rate,
                                    'weight_decay':weight_decay},
                       'eval_metric':{'name':eval_name},
                       'lr_scheduler':{'name':lr_name,
                                       'mode':mode,
                                       'factor':factor,
                                       'patience':patience},
                       'loaders':{'dataset':dataset,
                                       'batch_size':batch_size,
                                       'num_workers':num_workers,
                                       'raw_internal_path':raw_internal_path,
                                       'label_internal_path':label_internal_path,
                                       'weight_internal_path':weight_internal_path,
                       'train':{'file_paths':[file_paths_train],"slice_builder":{'name':slice_builder_name,
                                                                               'patch_shape':patch_shape,
                                                                               'stride_shape':stride_shape,
                                                                               'threshold':threshold,
                                                                               'slack_acceptance':slack_acceptance},
                       'transformer': {"raw": [{"name":name_transformer},
                                               {"name":ToTensor_name,
                                                "expand_dims":expand_dims_true}],
                                       "label": [{"name":name_transformer_label,
                                                "append_label":append_label},
                                               {"name":ToTensor_name,
                                                "expand_dims":expand_dims_false}]}},
                       'val':{"file_paths":[file_paths_val],"slice_builder":{'name':slice_builder_name,
                                                                               'patch_shape':patch_shape,
                                                                               'stride_shape':patch_shape,
                                                                               'threshold':threshold,
                                                                               'slack_acceptance':slack_acceptance},
                       'transformer': {"raw": [{"name":name_transformer},
                                               {"name":ToTensor_name,
                                                "expand_dims":expand_dims_true}],
                                       "label": [{"name":name_transformer_label,
                                                  "append_label":append_label},
                                               {"name":ToTensor_name,
                                                "expand_dims":expand_dims_false}]}}}}

with open(config_folder+'model_train.yaml', 'w') as yaml_file:
    yaml.dump(train_intrem_config, yaml_file, default_flow_style=False, sort_keys=False)

 #print(yaml.dump(train_intrem_config, default_flow_style=False, sort_keys=False))

# %% [markdown]
# Copy the text above and paste it after --config e.g. !predict3dunet --config /content/drive/MyDrive/3D_UNET/config_files/model_train.yaml
#
# if you want to use a previous model do not run the below cell or better yet # it out. If using an already trained model change
#
# model_path=checkpoint_dir+"best_checkpoint.pytorch" accordingly

# %%
#!train3dunet --config /content/drive/MyDrive/3D_UNET/config_files/model_train.yaml
# Out:
# 2024-10-15 00:58:29.314687: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-15 00:58:29.336023: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-15 00:58:29.342365: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-15 00:58:29.357398: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-15 00:58:30.554958: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-10-15 00:58:32,354 [MainThread] INFO TrainingSetup - {'model': {'name': 'UNet3D', 'in_channels': 1, 'out_channels': 1, 'layer_order': 'gcr', 'f_maps': [32, 64, 128, 256], 'num_groups': 8, 'final_sigmoid': True, 'is_segmentation': True}, 'trainer': {'checkpoint_dir': '/content/drive/MyDrive/3D_UNET/checkpoint_dir/', 'resume': None, 'pre_trained': None, 'validate_after_iters': 500, 'log_after_iters': 500, 'max_num_epochs': 10, 'max_num_iterations': 1800000, 'eval_score_higher_is_better': True}, 'loss': {'name': 'BCEWithLogitsLoss'}, 'optimizer': {'learning_rate': 0.0002, 'weight_decay': 1e-05}, 'eval_metric': {'name': 'MeanIoU'}, 'lr_scheduler': {'name': 'ReduceLROnPlateau', 'mode': 'max', 'factor': 0.2, 'patience': 30}, 'loaders': {'dataset': 'StandardHDF5Dataset', 'batch_size': 3, 'num_workers': 2, 'raw_internal_path': 'raw', 'label_internal_path': 'label', 'weight_internal_path': None, 'train': {'file_paths': ['/content/drive/MyDrive/3D_UNET/training_visit_3_transfer/train/'], 'slice_builder': {'name': 'SliceBuilder', 'patch_shape': [40, 170, 170], 'stride_shape': [20, 40, 40], 'threshold': 0.01, 'slack_acceptance': 0.01}, 'transformer': {'raw': [{'name': 'Standardize'}, {'name': 'ToTensor', 'expand_dims': True}], 'label': [{'name': 'BlobsToMask', 'append_label': False}, {'name': 'ToTensor', 'expand_dims': False}]}}, 'val': {'file_paths': ['/content/drive/MyDrive/3D_UNET/training_visit_3_transfer/qc/'], 'slice_builder': {'name': 'SliceBuilder', 'patch_shape': [40, 170, 170], 'stride_shape': [40, 170, 170], 'threshold': 0.01, 'slack_acceptance': 0.01}, 'transformer': {'raw': [{'name': 'Standardize'}, {'name': 'ToTensor', 'expand_dims': True}], 'label': [{'name': 'BlobsToMask', 'append_label': False}, {'name': 'ToTensor', 'expand_dims': False}]}}}, 'device': 'cuda'}
# 2024-10-15 00:58:32,600 [MainThread] INFO UNetTrainer - Number of learnable params 4081267
# 2024-10-15 00:58:32,601 [MainThread] INFO Dataset - Creating training and validation set loaders...
# 2024-10-15 00:58:32,712 [MainThread] INFO HDF5Dataset - Loading train set from: /content/drive/MyDrive/3D_UNET/training_visit_3_transfer/train/recon_sub__074_wheat_pcv_6days_R1_wb_1x_stitch.tif_022.h5...
# 2024-10-15 00:58:32,749 [MainThread] INFO Dataset - Slice builder config: {'name': 'SliceBuilder', 'patch_shape': [40, 170, 170], 'stride_shape': [20, 40, 40], 'threshold': 0.01, 'slack_acceptance': 0.01}
# 2024-10-15 00:58:32,804 [MainThread] INFO HDF5Dataset - Number of patches: 2500
# 2024-10-15 00:58:32,804 [MainThread] INFO HDF5Dataset - Loading train set from: /content/drive/MyDrive/3D_UNET/training_visit_3_transfer/train/recon_sub__095_corn_pvc_4days_R1_wb_1x_stitch.tif_031.h5...
# 2024-10-15 00:58:32,838 [MainThread] INFO Dataset - Slice builder config: {'name': 'SliceBuilder', 'patch_shape': [40, 170, 170], 'stride_shape': [20, 40, 40], 'threshold': 0.01, 'slack_acceptance': 0.01}
# 2024-10-15 00:58:32,873 [MainThread] INFO HDF5Dataset - Number of patches: 2500
# 2024-10-15 00:58:32,873 [MainThread] INFO HDF5Dataset - Loading train set from: /content/drive/MyDrive/3D_UNET/training_visit_3_transfer/train/recon_sub__104_wheat_pvc_ww_R5_wb_1x_stitch.tif_002.h5...
# 2024-10-15 00:58:32,906 [MainThread] INFO Dataset - Slice builder config: {'name': 'SliceBuilder', 'patch_shape': [40, 170, 170], 'stride_shape': [20, 40, 40], 'threshold': 0.01, 'slack_acceptance': 0.01}
# 2024-10-15 00:58:33,436 [MainThread] INFO HDF5Dataset - Number of patches: 2500
# 2024-10-15 00:58:33,438 [MainThread] INFO HDF5Dataset - Loading val set from: /content/drive/MyDrive/3D_UNET/training_visit_3_transfer/qc/recon_sub__073_corn_pcv_ww_R5_wb_1x_stitch_6.tif_003.h5...
# 2024-10-15 00:58:33,446 [MainThread] INFO Dataset - Slice builder config: {'name': 'SliceBuilder', 'patch_shape': [40, 170, 170], 'stride_shape': [40, 170, 170], 'threshold': 0.01, 'slack_acceptance': 0.01}
# 2024-10-15 00:58:33,451 [MainThread] INFO HDF5Dataset - Number of patches: 208
# 2024-10-15 00:58:33,451 [MainThread] INFO HDF5Dataset - Loading val set from: /content/drive/MyDrive/3D_UNET/training_visit_3_transfer/qc/recon_sub__103_wheat_pvc_4days_R3_wb_1x_stitch.tif_011.h5...
# 2024-10-15 00:58:33,459 [MainThread] INFO Dataset - Slice builder config: {'name': 'SliceBuilder', 'patch_shape': [40, 170, 170], 'stride_shape': [40, 170, 170], 'threshold': 0.01, 'slack_acceptance': 0.01}
# 2024-10-15 00:58:33,462 [MainThread] INFO HDF5Dataset - Number of patches: 208
# 2024-10-15 00:58:33,462 [MainThread] INFO HDF5Dataset - Loading val set from: /content/drive/MyDrive/3D_UNET/training_visit_3_transfer/qc/recon_sub__104_wheat_pvc_ww_R5_wb_1x_stitch.tif_002.h5...
# 2024-10-15 00:58:33,468 [MainThread] INFO Dataset - Slice builder config: {'name': 'SliceBuilder', 'patch_shape': [40, 170, 170], 'stride_shape': [40, 170, 170], 'threshold': 0.01, 'slack_acceptance': 0.01}
# 2024-10-15 00:58:33,472 [MainThread] INFO HDF5Dataset - Number of patches: 208
# 2024-10-15 00:58:33,472 [MainThread] INFO Dataset - Number of workers for train/val dataloader: 2
# 2024-10-15 00:58:33,473 [MainThread] INFO Dataset - Batch size for train/val loader: 3
# 2024-10-15 00:58:34,487 [MainThread] INFO UNetTrainer - UNet3D(
#   (encoders): ModuleList(
#     (0): Encoder(
#       (basic_module): DoubleConv(
#         (SingleConv1): SingleConv(
#           (groupnorm): GroupNorm(1, 1, eps=1e-05, affine=True)
#           (conv): Conv3d(1, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#         (SingleConv2): SingleConv(
#           (groupnorm): GroupNorm(8, 16, eps=1e-05, affine=True)
#           (conv): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#       )
#     )
#     (1): Encoder(
#       (pooling): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (basic_module): DoubleConv(
#         (SingleConv1): SingleConv(
#           (groupnorm): GroupNorm(8, 32, eps=1e-05, affine=True)
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#         (SingleConv2): SingleConv(
#           (groupnorm): GroupNorm(8, 32, eps=1e-05, affine=True)
#           (conv): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#       )
#     )
#     (2): Encoder(
#       (pooling): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (basic_module): DoubleConv(
#         (SingleConv1): SingleConv(
#           (groupnorm): GroupNorm(8, 64, eps=1e-05, affine=True)
#           (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#         (SingleConv2): SingleConv(
#           (groupnorm): GroupNorm(8, 64, eps=1e-05, affine=True)
#           (conv): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#       )
#     )
#     (3): Encoder(
#       (pooling): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (basic_module): DoubleConv(
#         (SingleConv1): SingleConv(
#           (groupnorm): GroupNorm(8, 128, eps=1e-05, affine=True)
#           (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#         (SingleConv2): SingleConv(
#           (groupnorm): GroupNorm(8, 128, eps=1e-05, affine=True)
#           (conv): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (decoders): ModuleList(
#     (0): Decoder(
#       (upsampling): InterpolateUpsampling()
#       (basic_module): DoubleConv(
#         (SingleConv1): SingleConv(
#           (groupnorm): GroupNorm(8, 384, eps=1e-05, affine=True)
#           (conv): Conv3d(384, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#         (SingleConv2): SingleConv(
#           (groupnorm): GroupNorm(8, 128, eps=1e-05, affine=True)
#           (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#       )
#     )
#     (1): Decoder(
#       (upsampling): InterpolateUpsampling()
#       (basic_module): DoubleConv(
#         (SingleConv1): SingleConv(
#           (groupnorm): GroupNorm(8, 192, eps=1e-05, affine=True)
#           (conv): Conv3d(192, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#         (SingleConv2): SingleConv(
#           (groupnorm): GroupNorm(8, 64, eps=1e-05, affine=True)
#           (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#       )
#     )
#     (2): Decoder(
#       (upsampling): InterpolateUpsampling()
#       (basic_module): DoubleConv(
#         (SingleConv1): SingleConv(
#           (groupnorm): GroupNorm(8, 96, eps=1e-05, affine=True)
#           (conv): Conv3d(96, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#         (SingleConv2): SingleConv(
#           (groupnorm): GroupNorm(8, 32, eps=1e-05, affine=True)
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (final_conv): Conv3d(32, 1, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#   (final_activation): Sigmoid()
# )
# 2024-10-15 00:58:34,488 [MainThread] INFO UNetTrainer - eval_score_higher_is_better: True
# 2024-10-15 00:58:36,324 [MainThread] INFO UNetTrainer - Training iteration [1/1800000]. Epoch [0/9]
# 2024-10-15 00:58:40,132 [MainThread] INFO UNetTrainer - Training iteration [2/1800000]. Epoch [0/9]
# 2024-10-15 00:58:40,668 [MainThread] INFO UNetTrainer - Training iteration [3/1800000]. Epoch [0/9]
# 2024-10-15 00:58:42,449 [MainThread] INFO UNetTrainer - Training iteration [4/1800000]. Epoch [0/9]
# 2024-10-15 00:58:44,230 [MainThread] INFO UNetTrainer - Training iteration [5/1800000]. Epoch [0/9]
# 2024-10-15 00:58:45,993 [MainThread] INFO UNetTrainer - Training iteration [6/1800000]. Epoch [0/9]
# 2024-10-15 00:58:47,772 [MainThread] INFO UNetTrainer - Training iteration [7/1800000]. Epoch [0/9]
# 2024-10-15 00:58:49,559 [MainThread] INFO UNetTrainer - Training iteration [8/1800000]. Epoch [0/9]
# 2024-10-15 00:58:51,350 [MainThread] INFO UNetTrainer - Training iteration [9/1800000]. Epoch [0/9]
# 2024-10-15 00:58:53,134 [MainThread] INFO UNetTrainer - Training iteration [10/1800000]. Epoch [0/9]
# 2024-10-15 00:58:54,939 [MainThread] INFO UNetTrainer - Training iteration [11/1800000]. Epoch [0/9]
# 2024-10-15 00:58:56,733 [MainThread] INFO UNetTrainer - Training iteration [12/1800000]. Epoch [0/9]
# 2024-10-15 00:58:58,540 [MainThread] INFO UNetTrainer - Training iteration [13/1800000]. Epoch [0/9]
# 2024-10-15 00:59:00,348 [MainThread] INFO UNetTrainer - Training iteration [14/1800000]. Epoch [0/9]
# 2024-10-15 00:59:02,172 [MainThread] INFO UNetTrainer - Training iteration [15/1800000]. Epoch [0/9]
# 2024-10-15 00:59:03,980 [MainThread] INFO UNetTrainer - Training iteration [16/1800000]. Epoch [0/9]
# 2024-10-15 00:59:05,801 [MainThread] INFO UNetTrainer - Training iteration [17/1800000]. Epoch [0/9]
# 2024-10-15 00:59:07,626 [MainThread] INFO UNetTrainer - Training iteration [18/1800000]. Epoch [0/9]
# 2024-10-15 00:59:09,459 [MainThread] INFO UNetTrainer - Training iteration [19/1800000]. Epoch [0/9]
# 2024-10-15 00:59:11,319 [MainThread] INFO UNetTrainer - Training iteration [20/1800000]. Epoch [0/9]
# 2024-10-15 00:59:13,141 [MainThread] INFO UNetTrainer - Training iteration [21/1800000]. Epoch [0/9]
# 2024-10-15 00:59:14,990 [MainThread] INFO UNetTrainer - Training iteration [22/1800000]. Epoch [0/9]
# 2024-10-15 00:59:16,857 [MainThread] INFO UNetTrainer - Training iteration [23/1800000]. Epoch [0/9]
# 2024-10-15 00:59:18,707 [MainThread] INFO UNetTrainer - Training iteration [24/1800000]. Epoch [0/9]
# 2024-10-15 00:59:20,572 [MainThread] INFO UNetTrainer - Training iteration [25/1800000]. Epoch [0/9]
# 2024-10-15 00:59:22,442 [MainThread] INFO UNetTrainer - Training iteration [26/1800000]. Epoch [0/9]
# 2024-10-15 00:59:24,324 [MainThread] INFO UNetTrainer - Training iteration [27/1800000]. Epoch [0/9]
# 2024-10-15 00:59:26,202 [MainThread] INFO UNetTrainer - Training iteration [28/1800000]. Epoch [0/9]
# 2024-10-15 00:59:28,094 [MainThread] INFO UNetTrainer - Training iteration [29/1800000]. Epoch [0/9]
# 2024-10-15 00:59:29,986 [MainThread] INFO UNetTrainer - Training iteration [30/1800000]. Epoch [0/9]
# 2024-10-15 00:59:31,884 [MainThread] INFO UNetTrainer - Training iteration [31/1800000]. Epoch [0/9]
# 2024-10-15 00:59:33,795 [MainThread] INFO UNetTrainer - Training iteration [32/1800000]. Epoch [0/9]
# 2024-10-15 00:59:35,712 [MainThread] INFO UNetTrainer - Training iteration [33/1800000]. Epoch [0/9]
# 2024-10-15 00:59:37,637 [MainThread] INFO UNetTrainer - Training iteration [34/1800000]. Epoch [0/9]
# 2024-10-15 00:59:39,584 [MainThread] INFO UNetTrainer - Training iteration [35/1800000]. Epoch [0/9]
# 2024-10-15 00:59:41,522 [MainThread] INFO UNetTrainer - Training iteration [36/1800000]. Epoch [0/9]
# 2024-10-15 00:59:43,479 [MainThread] INFO UNetTrainer - Training iteration [37/1800000]. Epoch [0/9]
# 2024-10-15 00:59:45,416 [MainThread] INFO UNetTrainer - Training iteration [38/1800000]. Epoch [0/9]
# 2024-10-15 00:59:47,376 [MainThread] INFO UNetTrainer - Training iteration [39/1800000]. Epoch [0/9]
# 2024-10-15 00:59:49,348 [MainThread] INFO UNetTrainer - Training iteration [40/1800000]. Epoch [0/9]
# 2024-10-15 00:59:51,326 [MainThread] INFO UNetTrainer - Training iteration [41/1800000]. Epoch [0/9]
# 2024-10-15 00:59:53,307 [MainThread] INFO UNetTrainer - Training iteration [42/1800000]. Epoch [0/9]
# 2024-10-15 00:59:55,299 [MainThread] INFO UNetTrainer - Training iteration [43/1800000]. Epoch [0/9]
# 2024-10-15 00:59:57,299 [MainThread] INFO UNetTrainer - Training iteration [44/1800000]. Epoch [0/9]
# 2024-10-15 00:59:59,305 [MainThread] INFO UNetTrainer - Training iteration [45/1800000]. Epoch [0/9]
# 2024-10-15 01:00:01,317 [MainThread] INFO UNetTrainer - Training iteration [46/1800000]. Epoch [0/9]
# 2024-10-15 01:00:03,306 [MainThread] INFO UNetTrainer - Training iteration [47/1800000]. Epoch [0/9]
# 2024-10-15 01:00:05,328 [MainThread] INFO UNetTrainer - Training iteration [48/1800000]. Epoch [0/9]
# 2024-10-15 01:00:07,335 [MainThread] INFO UNetTrainer - Training iteration [49/1800000]. Epoch [0/9]
# 2024-10-15 01:00:09,337 [MainThread] INFO UNetTrainer - Training iteration [50/1800000]. Epoch [0/9]
# 2024-10-15 01:00:11,330 [MainThread] INFO UNetTrainer - Training iteration [51/1800000]. Epoch [0/9]
# 2024-10-15 01:00:13,324 [MainThread] INFO UNetTrainer - Training iteration [52/1800000]. Epoch [0/9]
# 2024-10-15 01:00:15,293 [MainThread] INFO UNetTrainer - Training iteration [53/1800000]. Epoch [0/9]
# 2024-10-15 01:00:17,265 [MainThread] INFO UNetTrainer - Training iteration [54/1800000]. Epoch [0/9]
# 2024-10-15 01:00:19,221 [MainThread] INFO UNetTrainer - Training iteration [55/1800000]. Epoch [0/9]
# 2024-10-15 01:00:21,174 [MainThread] INFO UNetTrainer - Training iteration [56/1800000]. Epoch [0/9]
# 2024-10-15 01:00:23,132 [MainThread] INFO UNetTrainer - Training iteration [57/1800000]. Epoch [0/9]
# 2024-10-15 01:00:25,068 [MainThread] INFO UNetTrainer - Training iteration [58/1800000]. Epoch [0/9]
# 2024-10-15 01:00:27,008 [MainThread] INFO UNetTrainer - Training iteration [59/1800000]. Epoch [0/9]
# 2024-10-15 01:00:28,942 [MainThread] INFO UNetTrainer - Training iteration [60/1800000]. Epoch [0/9]
# 2024-10-15 01:00:30,881 [MainThread] INFO UNetTrainer - Training iteration [61/1800000]. Epoch [0/9]
# 2024-10-15 01:00:32,822 [MainThread] INFO UNetTrainer - Training iteration [62/1800000]. Epoch [0/9]
# 2024-10-15 01:00:34,746 [MainThread] INFO UNetTrainer - Training iteration [63/1800000]. Epoch [0/9]
# 2024-10-15 01:00:36,659 [MainThread] INFO UNetTrainer - Training iteration [64/1800000]. Epoch [0/9]
# 2024-10-15 01:00:38,585 [MainThread] INFO UNetTrainer - Training iteration [65/1800000]. Epoch [0/9]
# 2024-10-15 01:00:40,514 [MainThread] INFO UNetTrainer - Training iteration [66/1800000]. Epoch [0/9]
# 2024-10-15 01:00:42,434 [MainThread] INFO UNetTrainer - Training iteration [67/1800000]. Epoch [0/9]
# 2024-10-15 01:00:44,355 [MainThread] INFO UNetTrainer - Training iteration [68/1800000]. Epoch [0/9]
# 2024-10-15 01:00:46,285 [MainThread] INFO UNetTrainer - Training iteration [69/1800000]. Epoch [0/9]
# 2024-10-15 01:00:48,209 [MainThread] INFO UNetTrainer - Training iteration [70/1800000]. Epoch [0/9]
# 2024-10-15 01:00:50,118 [MainThread] INFO UNetTrainer - Training iteration [71/1800000]. Epoch [0/9]
# 2024-10-15 01:00:52,040 [MainThread] INFO UNetTrainer - Training iteration [72/1800000]. Epoch [0/9]
# 2024-10-15 01:00:53,964 [MainThread] INFO UNetTrainer - Training iteration [73/1800000]. Epoch [0/9]
# 2024-10-15 01:00:55,890 [MainThread] INFO UNetTrainer - Training iteration [74/1800000]. Epoch [0/9]
# 2024-10-15 01:00:57,822 [MainThread] INFO UNetTrainer - Training iteration [75/1800000]. Epoch [0/9]
# 2024-10-15 01:00:59,753 [MainThread] INFO UNetTrainer - Training iteration [76/1800000]. Epoch [0/9]
# 2024-10-15 01:01:01,708 [MainThread] INFO UNetTrainer - Training iteration [77/1800000]. Epoch [0/9]
# 2024-10-15 01:01:03,642 [MainThread] INFO UNetTrainer - Training iteration [78/1800000]. Epoch [0/9]
# 2024-10-15 01:01:05,590 [MainThread] INFO UNetTrainer - Training iteration [79/1800000]. Epoch [0/9]
# 2024-10-15 01:01:07,545 [MainThread] INFO UNetTrainer - Training iteration [80/1800000]. Epoch [0/9]
# 2024-10-15 01:01:09,486 [MainThread] INFO UNetTrainer - Training iteration [81/1800000]. Epoch [0/9]
# 2024-10-15 01:01:11,439 [MainThread] INFO UNetTrainer - Training iteration [82/1800000]. Epoch [0/9]
# 2024-10-15 01:01:13,410 [MainThread] INFO UNetTrainer - Training iteration [83/1800000]. Epoch [0/9]
# 2024-10-15 01:01:15,358 [MainThread] INFO UNetTrainer - Training iteration [84/1800000]. Epoch [0/9]
# 2024-10-15 01:01:17,316 [MainThread] INFO UNetTrainer - Training iteration [85/1800000]. Epoch [0/9]
# 2024-10-15 01:01:19,280 [MainThread] INFO UNetTrainer - Training iteration [86/1800000]. Epoch [0/9]
# 2024-10-15 01:01:21,236 [MainThread] INFO UNetTrainer - Training iteration [87/1800000]. Epoch [0/9]
# 2024-10-15 01:01:23,194 [MainThread] INFO UNetTrainer - Training iteration [88/1800000]. Epoch [0/9]
# 2024-10-15 01:01:25,137 [MainThread] INFO UNetTrainer - Training iteration [89/1800000]. Epoch [0/9]
# 2024-10-15 01:01:27,089 [MainThread] INFO UNetTrainer - Training iteration [90/1800000]. Epoch [0/9]
# 2024-10-15 01:01:29,038 [MainThread] INFO UNetTrainer - Training iteration [91/1800000]. Epoch [0/9]
# 2024-10-15 01:01:30,982 [MainThread] INFO UNetTrainer - Training iteration [92/1800000]. Epoch [0/9]
# 2024-10-15 01:01:32,930 [MainThread] INFO UNetTrainer - Training iteration [93/1800000]. Epoch [0/9]
# 2024-10-15 01:01:34,890 [MainThread] INFO UNetTrainer - Training iteration [94/1800000]. Epoch [0/9]
# 2024-10-15 01:01:36,827 [MainThread] INFO UNetTrainer - Training iteration [95/1800000]. Epoch [0/9]
# 2024-10-15 01:01:38,791 [MainThread] INFO UNetTrainer - Training iteration [96/1800000]. Epoch [0/9]
# 2024-10-15 01:01:40,722 [MainThread] INFO UNetTrainer - Training iteration [97/1800000]. Epoch [0/9]
# 2024-10-15 01:01:42,668 [MainThread] INFO UNetTrainer - Training iteration [98/1800000]. Epoch [0/9]
# 2024-10-15 01:01:44,619 [MainThread] INFO UNetTrainer - Training iteration [99/1800000]. Epoch [0/9]
# 2024-10-15 01:01:46,564 [MainThread] INFO UNetTrainer - Training iteration [100/1800000]. Epoch [0/9]
# 2024-10-15 01:01:48,513 [MainThread] INFO UNetTrainer - Training iteration [101/1800000]. Epoch [0/9]
# 2024-10-15 01:01:50,460 [MainThread] INFO UNetTrainer - Training iteration [102/1800000]. Epoch [0/9]
# 2024-10-15 01:01:52,403 [MainThread] INFO UNetTrainer - Training iteration [103/1800000]. Epoch [0/9]
# 2024-10-15 01:01:54,347 [MainThread] INFO UNetTrainer - Training iteration [104/1800000]. Epoch [0/9]
# 2024-10-15 01:01:56,293 [MainThread] INFO UNetTrainer - Training iteration [105/1800000]. Epoch [0/9]
# 2024-10-15 01:01:58,220 [MainThread] INFO UNetTrainer - Training iteration [106/1800000]. Epoch [0/9]
# 2024-10-15 01:02:00,159 [MainThread] INFO UNetTrainer - Training iteration [107/1800000]. Epoch [0/9]
# 2024-10-15 01:02:02,103 [MainThread] INFO UNetTrainer - Training iteration [108/1800000]. Epoch [0/9]
# 2024-10-15 01:02:04,045 [MainThread] INFO UNetTrainer - Training iteration [109/1800000]. Epoch [0/9]
# 2024-10-15 01:02:05,983 [MainThread] INFO UNetTrainer - Training iteration [110/1800000]. Epoch [0/9]
# 2024-10-15 01:02:07,927 [MainThread] INFO UNetTrainer - Training iteration [111/1800000]. Epoch [0/9]
# 2024-10-15 01:02:09,882 [MainThread] INFO UNetTrainer - Training iteration [112/1800000]. Epoch [0/9]
# 2024-10-15 01:02:11,821 [MainThread] INFO UNetTrainer - Training iteration [113/1800000]. Epoch [0/9]
# 2024-10-15 01:02:13,752 [MainThread] INFO UNetTrainer - Training iteration [114/1800000]. Epoch [0/9]
# 2024-10-15 01:02:15,689 [MainThread] INFO UNetTrainer - Training iteration [115/1800000]. Epoch [0/9]
# 2024-10-15 01:02:17,633 [MainThread] INFO UNetTrainer - Training iteration [116/1800000]. Epoch [0/9]
# 2024-10-15 01:02:19,574 [MainThread] INFO UNetTrainer - Training iteration [117/1800000]. Epoch [0/9]
# 2024-10-15 01:02:21,519 [MainThread] INFO UNetTrainer - Training iteration [118/1800000]. Epoch [0/9]
# 2024-10-15 01:02:23,467 [MainThread] INFO UNetTrainer - Training iteration [119/1800000]. Epoch [0/9]
# 2024-10-15 01:02:25,413 [MainThread] INFO UNetTrainer - Training iteration [120/1800000]. Epoch [0/9]
# 2024-10-15 01:02:27,352 [MainThread] INFO UNetTrainer - Training iteration [121/1800000]. Epoch [0/9]
# 2024-10-15 01:02:29,292 [MainThread] INFO UNetTrainer - Training iteration [122/1800000]. Epoch [0/9]
# 2024-10-15 01:02:31,236 [MainThread] INFO UNetTrainer - Training iteration [123/1800000]. Epoch [0/9]
# 2024-10-15 01:02:33,180 [MainThread] INFO UNetTrainer - Training iteration [124/1800000]. Epoch [0/9]
# 2024-10-15 01:02:35,123 [MainThread] INFO UNetTrainer - Training iteration [125/1800000]. Epoch [0/9]
# 2024-10-15 01:02:37,070 [MainThread] INFO UNetTrainer - Training iteration [126/1800000]. Epoch [0/9]
# 2024-10-15 01:02:39,011 [MainThread] INFO UNetTrainer - Training iteration [127/1800000]. Epoch [0/9]
# 2024-10-15 01:02:40,960 [MainThread] INFO UNetTrainer - Training iteration [128/1800000]. Epoch [0/9]
# 2024-10-15 01:02:42,917 [MainThread] INFO UNetTrainer - Training iteration [129/1800000]. Epoch [0/9]
# 2024-10-15 01:02:44,856 [MainThread] INFO UNetTrainer - Training iteration [130/1800000]. Epoch [0/9]
# 2024-10-15 01:02:46,788 [MainThread] INFO UNetTrainer - Training iteration [131/1800000]. Epoch [0/9]
# 2024-10-15 01:02:48,734 [MainThread] INFO UNetTrainer - Training iteration [132/1800000]. Epoch [0/9]
# 2024-10-15 01:02:50,686 [MainThread] INFO UNetTrainer - Training iteration [133/1800000]. Epoch [0/9]
# 2024-10-15 01:02:52,628 [MainThread] INFO UNetTrainer - Training iteration [134/1800000]. Epoch [0/9]
# 2024-10-15 01:02:54,569 [MainThread] INFO UNetTrainer - Training iteration [135/1800000]. Epoch [0/9]
# 2024-10-15 01:02:56,525 [MainThread] INFO UNetTrainer - Training iteration [136/1800000]. Epoch [0/9]
# 2024-10-15 01:02:58,459 [MainThread] INFO UNetTrainer - Training iteration [137/1800000]. Epoch [0/9]
# 2024-10-15 01:03:00,412 [MainThread] INFO UNetTrainer - Training iteration [138/1800000]. Epoch [0/9]
# 2024-10-15 01:03:02,355 [MainThread] INFO UNetTrainer - Training iteration [139/1800000]. Epoch [0/9]
# 2024-10-15 01:03:04,300 [MainThread] INFO UNetTrainer - Training iteration [140/1800000]. Epoch [0/9]
# 2024-10-15 01:03:06,249 [MainThread] INFO UNetTrainer - Training iteration [141/1800000]. Epoch [0/9]
# 2024-10-15 01:03:08,196 [MainThread] INFO UNetTrainer - Training iteration [142/1800000]. Epoch [0/9]
# 2024-10-15 01:03:10,141 [MainThread] INFO UNetTrainer - Training iteration [143/1800000]. Epoch [0/9]
# 2024-10-15 01:03:12,094 [MainThread] INFO UNetTrainer - Training iteration [144/1800000]. Epoch [0/9]
# 2024-10-15 01:03:14,044 [MainThread] INFO UNetTrainer - Training iteration [145/1800000]. Epoch [0/9]
# 2024-10-15 01:03:16,002 [MainThread] INFO UNetTrainer - Training iteration [146/1800000]. Epoch [0/9]
# 2024-10-15 01:03:17,932 [MainThread] INFO UNetTrainer - Training iteration [147/1800000]. Epoch [0/9]
# 2024-10-15 01:03:19,883 [MainThread] INFO UNetTrainer - Training iteration [148/1800000]. Epoch [0/9]
# 2024-10-15 01:03:21,831 [MainThread] INFO UNetTrainer - Training iteration [149/1800000]. Epoch [0/9]
# 2024-10-15 01:03:23,782 [MainThread] INFO UNetTrainer - Training iteration [150/1800000]. Epoch [0/9]
# 2024-10-15 01:03:25,736 [MainThread] INFO UNetTrainer - Training iteration [151/1800000]. Epoch [0/9]
# 2024-10-15 01:03:27,686 [MainThread] INFO UNetTrainer - Training iteration [152/1800000]. Epoch [0/9]
# 2024-10-15 01:03:29,641 [MainThread] INFO UNetTrainer - Training iteration [153/1800000]. Epoch [0/9]
# 2024-10-15 01:03:31,600 [MainThread] INFO UNetTrainer - Training iteration [154/1800000]. Epoch [0/9]
# 2024-10-15 01:03:33,557 [MainThread] INFO UNetTrainer - Training iteration [155/1800000]. Epoch [0/9]
# 2024-10-15 01:03:35,496 [MainThread] INFO UNetTrainer - Training iteration [156/1800000]. Epoch [0/9]
# 2024-10-15 01:03:37,446 [MainThread] INFO UNetTrainer - Training iteration [157/1800000]. Epoch [0/9]
# 2024-10-15 01:03:39,399 [MainThread] INFO UNetTrainer - Training iteration [158/1800000]. Epoch [0/9]
# 2024-10-15 01:03:41,348 [MainThread] INFO UNetTrainer - Training iteration [159/1800000]. Epoch [0/9]
# 2024-10-15 01:03:43,298 [MainThread] INFO UNetTrainer - Training iteration [160/1800000]. Epoch [0/9]
# 2024-10-15 01:03:45,248 [MainThread] INFO UNetTrainer - Training iteration [161/1800000]. Epoch [0/9]
# 2024-10-15 01:03:47,206 [MainThread] INFO UNetTrainer - Training iteration [162/1800000]. Epoch [0/9]
# 2024-10-15 01:03:49,154 [MainThread] INFO UNetTrainer - Training iteration [163/1800000]. Epoch [0/9]
# 2024-10-15 01:03:51,087 [MainThread] INFO UNetTrainer - Training iteration [164/1800000]. Epoch [0/9]
# 2024-10-15 01:03:53,034 [MainThread] INFO UNetTrainer - Training iteration [165/1800000]. Epoch [0/9]
# 2024-10-15 01:03:54,977 [MainThread] INFO UNetTrainer - Training iteration [166/1800000]. Epoch [0/9]
# 2024-10-15 01:03:56,936 [MainThread] INFO UNetTrainer - Training iteration [167/1800000]. Epoch [0/9]
# 2024-10-15 01:03:58,869 [MainThread] INFO UNetTrainer - Training iteration [168/1800000]. Epoch [0/9]
# 2024-10-15 01:04:00,831 [MainThread] INFO UNetTrainer - Training iteration [169/1800000]. Epoch [0/9]
# 2024-10-15 01:04:02,769 [MainThread] INFO UNetTrainer - Training iteration [170/1800000]. Epoch [0/9]
# 2024-10-15 01:04:04,723 [MainThread] INFO UNetTrainer - Training iteration [171/1800000]. Epoch [0/9]
# 2024-10-15 01:04:06,667 [MainThread] INFO UNetTrainer - Training iteration [172/1800000]. Epoch [0/9]
# 2024-10-15 01:04:08,613 [MainThread] INFO UNetTrainer - Training iteration [173/1800000]. Epoch [0/9]
# 2024-10-15 01:04:10,562 [MainThread] INFO UNetTrainer - Training iteration [174/1800000]. Epoch [0/9]
# 2024-10-15 01:04:12,508 [MainThread] INFO UNetTrainer - Training iteration [175/1800000]. Epoch [0/9]
# 2024-10-15 01:04:14,455 [MainThread] INFO UNetTrainer - Training iteration [176/1800000]. Epoch [0/9]
# 2024-10-15 01:04:16,413 [MainThread] INFO UNetTrainer - Training iteration [177/1800000]. Epoch [0/9]
# 2024-10-15 01:04:18,361 [MainThread] INFO UNetTrainer - Training iteration [178/1800000]. Epoch [0/9]
# 2024-10-15 01:04:20,309 [MainThread] INFO UNetTrainer - Training iteration [179/1800000]. Epoch [0/9]
# 2024-10-15 01:04:22,272 [MainThread] INFO UNetTrainer - Training iteration [180/1800000]. Epoch [0/9]
# 2024-10-15 01:04:24,212 [MainThread] INFO UNetTrainer - Training iteration [181/1800000]. Epoch [0/9]
# 2024-10-15 01:04:26,165 [MainThread] INFO UNetTrainer - Training iteration [182/1800000]. Epoch [0/9]
# 2024-10-15 01:04:28,111 [MainThread] INFO UNetTrainer - Training iteration [183/1800000]. Epoch [0/9]
# 2024-10-15 01:04:30,064 [MainThread] INFO UNetTrainer - Training iteration [184/1800000]. Epoch [0/9]
# 2024-10-15 01:04:32,015 [MainThread] INFO UNetTrainer - Training iteration [185/1800000]. Epoch [0/9]
# 2024-10-15 01:04:33,975 [MainThread] INFO UNetTrainer - Training iteration [186/1800000]. Epoch [0/9]
# 2024-10-15 01:04:35,929 [MainThread] INFO UNetTrainer - Training iteration [187/1800000]. Epoch [0/9]
# 2024-10-15 01:04:37,885 [MainThread] INFO UNetTrainer - Training iteration [188/1800000]. Epoch [0/9]
# 2024-10-15 01:04:39,828 [MainThread] INFO UNetTrainer - Training iteration [189/1800000]. Epoch [0/9]
# 2024-10-15 01:04:41,777 [MainThread] INFO UNetTrainer - Training iteration [190/1800000]. Epoch [0/9]
# 2024-10-15 01:04:43,724 [MainThread] INFO UNetTrainer - Training iteration [191/1800000]. Epoch [0/9]
# 2024-10-15 01:04:45,677 [MainThread] INFO UNetTrainer - Training iteration [192/1800000]. Epoch [0/9]
# 2024-10-15 01:04:47,626 [MainThread] INFO UNetTrainer - Training iteration [193/1800000]. Epoch [0/9]
# 2024-10-15 01:04:49,588 [MainThread] INFO UNetTrainer - Training iteration [194/1800000]. Epoch [0/9]
# 2024-10-15 01:04:51,524 [MainThread] INFO UNetTrainer - Training iteration [195/1800000]. Epoch [0/9]
# 2024-10-15 01:04:53,474 [MainThread] INFO UNetTrainer - Training iteration [196/1800000]. Epoch [0/9]
# 2024-10-15 01:04:55,407 [MainThread] INFO UNetTrainer - Training iteration [197/1800000]. Epoch [0/9]
# 2024-10-15 01:04:57,360 [MainThread] INFO UNetTrainer - Training iteration [198/1800000]. Epoch [0/9]
# 2024-10-15 01:04:59,302 [MainThread] INFO UNetTrainer - Training iteration [199/1800000]. Epoch [0/9]
# 2024-10-15 01:05:01,247 [MainThread] INFO UNetTrainer - Training iteration [200/1800000]. Epoch [0/9]
# 2024-10-15 01:05:03,194 [MainThread] INFO UNetTrainer - Training iteration [201/1800000]. Epoch [0/9]
# 2024-10-15 01:05:05,149 [MainThread] INFO UNetTrainer - Training iteration [202/1800000]. Epoch [0/9]
# 2024-10-15 01:05:07,085 [MainThread] INFO UNetTrainer - Training iteration [203/1800000]. Epoch [0/9]
# 2024-10-15 01:05:09,033 [MainThread] INFO UNetTrainer - Training iteration [204/1800000]. Epoch [0/9]
# 2024-10-15 01:05:10,980 [MainThread] INFO UNetTrainer - Training iteration [205/1800000]. Epoch [0/9]
# 2024-10-15 01:05:12,923 [MainThread] INFO UNetTrainer - Training iteration [206/1800000]. Epoch [0/9]
# 2024-10-15 01:05:14,864 [MainThread] INFO UNetTrainer - Training iteration [207/1800000]. Epoch [0/9]
# 2024-10-15 01:05:16,807 [MainThread] INFO UNetTrainer - Training iteration [208/1800000]. Epoch [0/9]
# 2024-10-15 01:05:18,749 [MainThread] INFO UNetTrainer - Training iteration [209/1800000]. Epoch [0/9]
# 2024-10-15 01:05:20,692 [MainThread] INFO UNetTrainer - Training iteration [210/1800000]. Epoch [0/9]
# 2024-10-15 01:05:22,636 [MainThread] INFO UNetTrainer - Training iteration [211/1800000]. Epoch [0/9]
# 2024-10-15 01:05:24,578 [MainThread] INFO UNetTrainer - Training iteration [212/1800000]. Epoch [0/9]
# 2024-10-15 01:05:26,523 [MainThread] INFO UNetTrainer - Training iteration [213/1800000]. Epoch [0/9]
# 2024-10-15 01:05:28,472 [MainThread] INFO UNetTrainer - Training iteration [214/1800000]. Epoch [0/9]
# 2024-10-15 01:05:30,420 [MainThread] INFO UNetTrainer - Training iteration [215/1800000]. Epoch [0/9]
# 2024-10-15 01:05:32,371 [MainThread] INFO UNetTrainer - Training iteration [216/1800000]. Epoch [0/9]
# 2024-10-15 01:05:34,318 [MainThread] INFO UNetTrainer - Training iteration [217/1800000]. Epoch [0/9]
# 2024-10-15 01:05:36,264 [MainThread] INFO UNetTrainer - Training iteration [218/1800000]. Epoch [0/9]
# 2024-10-15 01:05:38,223 [MainThread] INFO UNetTrainer - Training iteration [219/1800000]. Epoch [0/9]
# 2024-10-15 01:05:40,158 [MainThread] INFO UNetTrainer - Training iteration [220/1800000]. Epoch [0/9]
# 2024-10-15 01:05:42,118 [MainThread] INFO UNetTrainer - Training iteration [221/1800000]. Epoch [0/9]
# 2024-10-15 01:05:44,054 [MainThread] INFO UNetTrainer - Training iteration [222/1800000]. Epoch [0/9]
# 2024-10-15 01:05:46,000 [MainThread] INFO UNetTrainer - Training iteration [223/1800000]. Epoch [0/9]
# 2024-10-15 01:05:47,948 [MainThread] INFO UNetTrainer - Training iteration [224/1800000]. Epoch [0/9]
# 2024-10-15 01:05:49,893 [MainThread] INFO UNetTrainer - Training iteration [225/1800000]. Epoch [0/9]
# 2024-10-15 01:05:51,835 [MainThread] INFO UNetTrainer - Training iteration [226/1800000]. Epoch [0/9]
# 2024-10-15 01:05:53,779 [MainThread] INFO UNetTrainer - Training iteration [227/1800000]. Epoch [0/9]
# 2024-10-15 01:05:55,730 [MainThread] INFO UNetTrainer - Training iteration [228/1800000]. Epoch [0/9]
# 2024-10-15 01:05:57,662 [MainThread] INFO UNetTrainer - Training iteration [229/1800000]. Epoch [0/9]
# 2024-10-15 01:05:59,609 [MainThread] INFO UNetTrainer - Training iteration [230/1800000]. Epoch [0/9]
# 2024-10-15 01:06:01,540 [MainThread] INFO UNetTrainer - Training iteration [231/1800000]. Epoch [0/9]
# 2024-10-15 01:06:03,479 [MainThread] INFO UNetTrainer - Training iteration [232/1800000]. Epoch [0/9]
# 2024-10-15 01:06:05,421 [MainThread] INFO UNetTrainer - Training iteration [233/1800000]. Epoch [0/9]
# 2024-10-15 01:06:07,360 [MainThread] INFO UNetTrainer - Training iteration [234/1800000]. Epoch [0/9]
# 2024-10-15 01:06:09,303 [MainThread] INFO UNetTrainer - Training iteration [235/1800000]. Epoch [0/9]
# 2024-10-15 01:06:11,251 [MainThread] INFO UNetTrainer - Training iteration [236/1800000]. Epoch [0/9]
# 2024-10-15 01:06:13,185 [MainThread] INFO UNetTrainer - Training iteration [237/1800000]. Epoch [0/9]
# 2024-10-15 01:06:15,126 [MainThread] INFO UNetTrainer - Training iteration [238/1800000]. Epoch [0/9]
# 2024-10-15 01:06:17,063 [MainThread] INFO UNetTrainer - Training iteration [239/1800000]. Epoch [0/9]
# 2024-10-15 01:06:19,004 [MainThread] INFO UNetTrainer - Training iteration [240/1800000]. Epoch [0/9]
# 2024-10-15 01:06:20,943 [MainThread] INFO UNetTrainer - Training iteration [241/1800000]. Epoch [0/9]
# 2024-10-15 01:06:22,884 [MainThread] INFO UNetTrainer - Training iteration [242/1800000]. Epoch [0/9]
# 2024-10-15 01:06:24,824 [MainThread] INFO UNetTrainer - Training iteration [243/1800000]. Epoch [0/9]
# 2024-10-15 01:06:26,766 [MainThread] INFO UNetTrainer - Training iteration [244/1800000]. Epoch [0/9]
# 2024-10-15 01:06:28,709 [MainThread] INFO UNetTrainer - Training iteration [245/1800000]. Epoch [0/9]
# 2024-10-15 01:06:30,652 [MainThread] INFO UNetTrainer - Training iteration [246/1800000]. Epoch [0/9]
# 2024-10-15 01:06:32,597 [MainThread] INFO UNetTrainer - Training iteration [247/1800000]. Epoch [0/9]
# 2024-10-15 01:06:34,525 [MainThread] INFO UNetTrainer - Training iteration [248/1800000]. Epoch [0/9]
# 2024-10-15 01:06:36,467 [MainThread] INFO UNetTrainer - Training iteration [249/1800000]. Epoch [0/9]
# 2024-10-15 01:06:38,413 [MainThread] INFO UNetTrainer - Training iteration [250/1800000]. Epoch [0/9]
# 2024-10-15 01:06:40,353 [MainThread] INFO UNetTrainer - Training iteration [251/1800000]. Epoch [0/9]
# 2024-10-15 01:06:42,298 [MainThread] INFO UNetTrainer - Training iteration [252/1800000]. Epoch [0/9]
# 2024-10-15 01:06:44,243 [MainThread] INFO UNetTrainer - Training iteration [253/1800000]. Epoch [0/9]
# 2024-10-15 01:06:46,190 [MainThread] INFO UNetTrainer - Training iteration [254/1800000]. Epoch [0/9]
# 2024-10-15 01:06:48,137 [MainThread] INFO UNetTrainer - Training iteration [255/1800000]. Epoch [0/9]
# 2024-10-15 01:06:50,076 [MainThread] INFO UNetTrainer - Training iteration [256/1800000]. Epoch [0/9]
# 2024-10-15 01:06:52,019 [MainThread] INFO UNetTrainer - Training iteration [257/1800000]. Epoch [0/9]
# 2024-10-15 01:06:53,968 [MainThread] INFO UNetTrainer - Training iteration [258/1800000]. Epoch [0/9]
# 2024-10-15 01:06:55,913 [MainThread] INFO UNetTrainer - Training iteration [259/1800000]. Epoch [0/9]
# 2024-10-15 01:06:57,856 [MainThread] INFO UNetTrainer - Training iteration [260/1800000]. Epoch [0/9]
# 2024-10-15 01:06:59,809 [MainThread] INFO UNetTrainer - Training iteration [261/1800000]. Epoch [0/9]
# 2024-10-15 01:07:01,743 [MainThread] INFO UNetTrainer - Training iteration [262/1800000]. Epoch [0/9]
# 2024-10-15 01:07:03,693 [MainThread] INFO UNetTrainer - Training iteration [263/1800000]. Epoch [0/9]
# 2024-10-15 01:07:05,636 [MainThread] INFO UNetTrainer - Training iteration [264/1800000]. Epoch [0/9]
# 2024-10-15 01:07:07,585 [MainThread] INFO UNetTrainer - Training iteration [265/1800000]. Epoch [0/9]
# 2024-10-15 01:07:09,531 [MainThread] INFO UNetTrainer - Training iteration [266/1800000]. Epoch [0/9]
# 2024-10-15 01:07:11,492 [MainThread] INFO UNetTrainer - Training iteration [267/1800000]. Epoch [0/9]
# 2024-10-15 01:07:13,438 [MainThread] INFO UNetTrainer - Training iteration [268/1800000]. Epoch [0/9]
# 2024-10-15 01:07:15,384 [MainThread] INFO UNetTrainer - Training iteration [269/1800000]. Epoch [0/9]
# 2024-10-15 01:07:17,327 [MainThread] INFO UNetTrainer - Training iteration [270/1800000]. Epoch [0/9]
# 2024-10-15 01:07:19,281 [MainThread] INFO UNetTrainer - Training iteration [271/1800000]. Epoch [0/9]
# 2024-10-15 01:07:21,220 [MainThread] INFO UNetTrainer - Training iteration [272/1800000]. Epoch [0/9]
# 2024-10-15 01:07:23,162 [MainThread] INFO UNetTrainer - Training iteration [273/1800000]. Epoch [0/9]
# 2024-10-15 01:07:25,107 [MainThread] INFO UNetTrainer - Training iteration [274/1800000]. Epoch [0/9]
# 2024-10-15 01:07:27,057 [MainThread] INFO UNetTrainer - Training iteration [275/1800000]. Epoch [0/9]
# 2024-10-15 01:07:29,003 [MainThread] INFO UNetTrainer - Training iteration [276/1800000]. Epoch [0/9]
# 2024-10-15 01:07:30,954 [MainThread] INFO UNetTrainer - Training iteration [277/1800000]. Epoch [0/9]
# 2024-10-15 01:07:32,904 [MainThread] INFO UNetTrainer - Training iteration [278/1800000]. Epoch [0/9]
# 2024-10-15 01:07:34,851 [MainThread] INFO UNetTrainer - Training iteration [279/1800000]. Epoch [0/9]
# 2024-10-15 01:07:36,788 [MainThread] INFO UNetTrainer - Training iteration [280/1800000]. Epoch [0/9]
# 2024-10-15 01:07:38,728 [MainThread] INFO UNetTrainer - Training iteration [281/1800000]. Epoch [0/9]
# 2024-10-15 01:07:40,672 [MainThread] INFO UNetTrainer - Training iteration [282/1800000]. Epoch [0/9]
# 2024-10-15 01:07:42,614 [MainThread] INFO UNetTrainer - Training iteration [283/1800000]. Epoch [0/9]
# 2024-10-15 01:07:44,559 [MainThread] INFO UNetTrainer - Training iteration [284/1800000]. Epoch [0/9]
# 2024-10-15 01:07:46,503 [MainThread] INFO UNetTrainer - Training iteration [285/1800000]. Epoch [0/9]
# 2024-10-15 01:07:48,453 [MainThread] INFO UNetTrainer - Training iteration [286/1800000]. Epoch [0/9]
# 2024-10-15 01:07:50,393 [MainThread] INFO UNetTrainer - Training iteration [287/1800000]. Epoch [0/9]
# 2024-10-15 01:07:52,348 [MainThread] INFO UNetTrainer - Training iteration [288/1800000]. Epoch [0/9]
# 2024-10-15 01:07:54,281 [MainThread] INFO UNetTrainer - Training iteration [289/1800000]. Epoch [0/9]
# 2024-10-15 01:07:56,230 [MainThread] INFO UNetTrainer - Training iteration [290/1800000]. Epoch [0/9]
# 2024-10-15 01:07:58,174 [MainThread] INFO UNetTrainer - Training iteration [291/1800000]. Epoch [0/9]
# 2024-10-15 01:08:00,120 [MainThread] INFO UNetTrainer - Training iteration [292/1800000]. Epoch [0/9]
# 2024-10-15 01:08:02,074 [MainThread] INFO UNetTrainer - Training iteration [293/1800000]. Epoch [0/9]
# 2024-10-15 01:08:04,031 [MainThread] INFO UNetTrainer - Training iteration [294/1800000]. Epoch [0/9]
# 2024-10-15 01:08:05,984 [MainThread] INFO UNetTrainer - Training iteration [295/1800000]. Epoch [0/9]
# 2024-10-15 01:08:07,928 [MainThread] INFO UNetTrainer - Training iteration [296/1800000]. Epoch [0/9]
# 2024-10-15 01:08:09,871 [MainThread] INFO UNetTrainer - Training iteration [297/1800000]. Epoch [0/9]
# 2024-10-15 01:08:11,820 [MainThread] INFO UNetTrainer - Training iteration [298/1800000]. Epoch [0/9]
# 2024-10-15 01:08:13,767 [MainThread] INFO UNetTrainer - Training iteration [299/1800000]. Epoch [0/9]
# 2024-10-15 01:08:15,717 [MainThread] INFO UNetTrainer - Training iteration [300/1800000]. Epoch [0/9]
# 2024-10-15 01:08:17,665 [MainThread] INFO UNetTrainer - Training iteration [301/1800000]. Epoch [0/9]
# 2024-10-15 01:08:19,629 [MainThread] INFO UNetTrainer - Training iteration [302/1800000]. Epoch [0/9]
# 2024-10-15 01:08:21,567 [MainThread] INFO UNetTrainer - Training iteration [303/1800000]. Epoch [0/9]
# 2024-10-15 01:08:23,516 [MainThread] INFO UNetTrainer - Training iteration [304/1800000]. Epoch [0/9]
# 2024-10-15 01:08:25,448 [MainThread] INFO UNetTrainer - Training iteration [305/1800000]. Epoch [0/9]
# 2024-10-15 01:08:27,395 [MainThread] INFO UNetTrainer - Training iteration [306/1800000]. Epoch [0/9]
# 2024-10-15 01:08:29,343 [MainThread] INFO UNetTrainer - Training iteration [307/1800000]. Epoch [0/9]
# 2024-10-15 01:08:31,288 [MainThread] INFO UNetTrainer - Training iteration [308/1800000]. Epoch [0/9]
# 2024-10-15 01:08:33,237 [MainThread] INFO UNetTrainer - Training iteration [309/1800000]. Epoch [0/9]
# 2024-10-15 01:08:35,183 [MainThread] INFO UNetTrainer - Training iteration [310/1800000]. Epoch [0/9]
# 2024-10-15 01:08:37,142 [MainThread] INFO UNetTrainer - Training iteration [311/1800000]. Epoch [0/9]
# 2024-10-15 01:08:39,088 [MainThread] INFO UNetTrainer - Training iteration [312/1800000]. Epoch [0/9]
# 2024-10-15 01:08:41,023 [MainThread] INFO UNetTrainer - Training iteration [313/1800000]. Epoch [0/9]
# 2024-10-15 01:08:42,969 [MainThread] INFO UNetTrainer - Training iteration [314/1800000]. Epoch [0/9]
# 2024-10-15 01:08:44,917 [MainThread] INFO UNetTrainer - Training iteration [315/1800000]. Epoch [0/9]
# 2024-10-15 01:08:46,869 [MainThread] INFO UNetTrainer - Training iteration [316/1800000]. Epoch [0/9]
# 2024-10-15 01:08:48,821 [MainThread] INFO UNetTrainer - Training iteration [317/1800000]. Epoch [0/9]
# 2024-10-15 01:08:50,767 [MainThread] INFO UNetTrainer - Training iteration [318/1800000]. Epoch [0/9]
# 2024-10-15 01:08:52,719 [MainThread] INFO UNetTrainer - Training iteration [319/1800000]. Epoch [0/9]
# 2024-10-15 01:08:54,675 [MainThread] INFO UNetTrainer - Training iteration [320/1800000]. Epoch [0/9]
# 2024-10-15 01:08:56,633 [MainThread] INFO UNetTrainer - Training iteration [321/1800000]. Epoch [0/9]
# 2024-10-15 01:08:58,566 [MainThread] INFO UNetTrainer - Training iteration [322/1800000]. Epoch [0/9]
# 2024-10-15 01:09:00,521 [MainThread] INFO UNetTrainer - Training iteration [323/1800000]. Epoch [0/9]
# 2024-10-15 01:09:02,471 [MainThread] INFO UNetTrainer - Training iteration [324/1800000]. Epoch [0/9]
# 2024-10-15 01:09:04,434 [MainThread] INFO UNetTrainer - Training iteration [325/1800000]. Epoch [0/9]
# 2024-10-15 01:09:06,371 [MainThread] INFO UNetTrainer - Training iteration [326/1800000]. Epoch [0/9]
# 2024-10-15 01:09:08,321 [MainThread] INFO UNetTrainer - Training iteration [327/1800000]. Epoch [0/9]
# 2024-10-15 01:09:10,278 [MainThread] INFO UNetTrainer - Training iteration [328/1800000]. Epoch [0/9]
# 2024-10-15 01:09:12,217 [MainThread] INFO UNetTrainer - Training iteration [329/1800000]. Epoch [0/9]
# 2024-10-15 01:09:14,160 [MainThread] INFO UNetTrainer - Training iteration [330/1800000]. Epoch [0/9]
# 2024-10-15 01:09:16,111 [MainThread] INFO UNetTrainer - Training iteration [331/1800000]. Epoch [0/9]
# 2024-10-15 01:09:18,054 [MainThread] INFO UNetTrainer - Training iteration [332/1800000]. Epoch [0/9]
# 2024-10-15 01:09:19,992 [MainThread] INFO UNetTrainer - Training iteration [333/1800000]. Epoch [0/9]
# 2024-10-15 01:09:21,932 [MainThread] INFO UNetTrainer - Training iteration [334/1800000]. Epoch [0/9]
# 2024-10-15 01:09:23,882 [MainThread] INFO UNetTrainer - Training iteration [335/1800000]. Epoch [0/9]
# 2024-10-15 01:09:25,828 [MainThread] INFO UNetTrainer - Training iteration [336/1800000]. Epoch [0/9]
# 2024-10-15 01:09:27,781 [MainThread] INFO UNetTrainer - Training iteration [337/1800000]. Epoch [0/9]
# 2024-10-15 01:09:29,713 [MainThread] INFO UNetTrainer - Training iteration [338/1800000]. Epoch [0/9]
# 2024-10-15 01:09:31,659 [MainThread] INFO UNetTrainer - Training iteration [339/1800000]. Epoch [0/9]
# 2024-10-15 01:09:33,605 [MainThread] INFO UNetTrainer - Training iteration [340/1800000]. Epoch [0/9]
# 2024-10-15 01:09:35,553 [MainThread] INFO UNetTrainer - Training iteration [341/1800000]. Epoch [0/9]
# 2024-10-15 01:09:37,496 [MainThread] INFO UNetTrainer - Training iteration [342/1800000]. Epoch [0/9]
# 2024-10-15 01:09:39,440 [MainThread] INFO UNetTrainer - Training iteration [343/1800000]. Epoch [0/9]
# 2024-10-15 01:09:41,390 [MainThread] INFO UNetTrainer - Training iteration [344/1800000]. Epoch [0/9]
# 2024-10-15 01:09:43,323 [MainThread] INFO UNetTrainer - Training iteration [345/1800000]. Epoch [0/9]
# 2024-10-15 01:09:45,271 [MainThread] INFO UNetTrainer - Training iteration [346/1800000]. Epoch [0/9]
# 2024-10-15 01:09:47,206 [MainThread] INFO UNetTrainer - Training iteration [347/1800000]. Epoch [0/9]
# 2024-10-15 01:09:49,150 [MainThread] INFO UNetTrainer - Training iteration [348/1800000]. Epoch [0/9]
# 2024-10-15 01:09:51,097 [MainThread] INFO UNetTrainer - Training iteration [349/1800000]. Epoch [0/9]
# 2024-10-15 01:09:53,039 [MainThread] INFO UNetTrainer - Training iteration [350/1800000]. Epoch [0/9]
# 2024-10-15 01:09:54,981 [MainThread] INFO UNetTrainer - Training iteration [351/1800000]. Epoch [0/9]
# 2024-10-15 01:09:56,932 [MainThread] INFO UNetTrainer - Training iteration [352/1800000]. Epoch [0/9]
# 2024-10-15 01:09:58,874 [MainThread] INFO UNetTrainer - Training iteration [353/1800000]. Epoch [0/9]
# 2024-10-15 01:10:00,820 [MainThread] INFO UNetTrainer - Training iteration [354/1800000]. Epoch [0/9]
# 2024-10-15 01:10:02,749 [MainThread] INFO UNetTrainer - Training iteration [355/1800000]. Epoch [0/9]
# 2024-10-15 01:10:04,691 [MainThread] INFO UNetTrainer - Training iteration [356/1800000]. Epoch [0/9]
# 2024-10-15 01:10:06,639 [MainThread] INFO UNetTrainer - Training iteration [357/1800000]. Epoch [0/9]
# 2024-10-15 01:10:08,575 [MainThread] INFO UNetTrainer - Training iteration [358/1800000]. Epoch [0/9]
# 2024-10-15 01:10:10,516 [MainThread] INFO UNetTrainer - Training iteration [359/1800000]. Epoch [0/9]
# 2024-10-15 01:10:12,470 [MainThread] INFO UNetTrainer - Training iteration [360/1800000]. Epoch [0/9]
# 2024-10-15 01:10:14,405 [MainThread] INFO UNetTrainer - Training iteration [361/1800000]. Epoch [0/9]
# 2024-10-15 01:10:16,355 [MainThread] INFO UNetTrainer - Training iteration [362/1800000]. Epoch [0/9]
# 2024-10-15 01:10:18,285 [MainThread] INFO UNetTrainer - Training iteration [363/1800000]. Epoch [0/9]
# 2024-10-15 01:10:20,223 [MainThread] INFO UNetTrainer - Training iteration [364/1800000]. Epoch [0/9]
# ...
# 2024-10-15 02:49:00,626 [MainThread] INFO UNetTrainer - Training iteration [3010/1800000]. Epoch [1/9]
# 2024-10-15 02:49:02,569 [MainThread] INFO UNetTrainer - Training iteration [3011/1800000]. Epoch [1/9]
# 2024-10-15 02:49:04,511 [MainThread] INFO UNetTrainer - Training iteration [3012/1800000]. Epoch [1/9]
# 2024-10-15 02:49:06,452 [MainThread] INFO UNetTrainer - Training iteration [3013/1800000]. Epoch [1/9]
# 2024-10-15 02:49:08,406 [MainThread] INFO UNetTrainer - Training iteration [3014/1800000]. Epoch [1/9]
# 2024-10-15 02:49:10,337 [MainThread] INFO UNetTrainer - Training iteration [3015/1800000]. Epoch [1/9]
# 2024-10-15 02:49:12,276 [MainThread] INFO UNetTrainer - Training iteration [3016/1800000]. Epoch [1/9]
# 2024-10-15 02:49:14,219 [MainThread] INFO UNetTrainer - Training iteration [3017/1800000]. Epoch [1/9]
# 2024-10-15 02:49:16,161 [MainThread] INFO UNetTrainer - Training iteration [3018/1800000]. Epoch [1/9]
# 2024-10-15 02:49:18,104 [MainThread] INFO UNetTrainer - Training iteration [3019/1800000]. Epoch [1/9]
# 2024-10-15 02:49:20,047 [MainThread] INFO UNetTrainer - Training iteration [3020/1800000]. Epoch [1/9]
# 2024-10-15 02:49:21,990 [MainThread] INFO UNetTrainer - Training iteration [3021/1800000]. Epoch [1/9]
# 2024-10-15 02:49:23,930 [MainThread] INFO UNetTrainer - Training iteration [3022/1800000]. Epoch [1/9]
# 2024-10-15 02:49:25,875 [MainThread] INFO UNetTrainer - Training iteration [3023/1800000]. Epoch [1/9]
# 2024-10-15 02:49:27,810 [MainThread] INFO UNetTrainer - Training iteration [3024/1800000]. Epoch [1/9]
# 2024-10-15 02:49:29,748 [MainThread] INFO UNetTrainer - Training iteration [3025/1800000]. Epoch [1/9]
# 2024-10-15 02:49:31,691 [MainThread] INFO UNetTrainer - Training iteration [3026/1800000]. Epoch [1/9]
# 2024-10-15 02:49:33,634 [MainThread] INFO UNetTrainer - Training iteration [3027/1800000]. Epoch [1/9]
# 2024-10-15 02:49:35,573 [MainThread] INFO UNetTrainer - Training iteration [3028/1800000]. Epoch [1/9]
# 2024-10-15 02:49:37,515 [MainThread] INFO UNetTrainer - Training iteration [3029/1800000]. Epoch [1/9]
# 2024-10-15 02:49:39,465 [MainThread] INFO UNetTrainer - Training iteration [3030/1800000]. Epoch [1/9]
# 2024-10-15 02:49:41,405 [MainThread] INFO UNetTrainer - Training iteration [3031/1800000]. Epoch [1/9]
# 2024-10-15 02:49:43,345 [MainThread] INFO UNetTrainer - Training iteration [3032/1800000]. Epoch [1/9]
# 2024-10-15 02:49:45,285 [MainThread] INFO UNetTrainer - Training iteration [3033/1800000]. Epoch [1/9]
# 2024-10-15 02:49:47,224 [MainThread] INFO UNetTrainer - Training iteration [3034/1800000]. Epoch [1/9]
# 2024-10-15 02:49:49,164 [MainThread] INFO UNetTrainer - Training iteration [3035/1800000]. Epoch [1/9]
# 2024-10-15 02:49:51,107 [MainThread] INFO UNetTrainer - Training iteration [3036/1800000]. Epoch [1/9]
# 2024-10-15 02:49:53,051 [MainThread] INFO UNetTrainer - Training iteration [3037/1800000]. Epoch [1/9]
# 2024-10-15 02:49:55,008 [MainThread] INFO UNetTrainer - Training iteration [3038/1800000]. Epoch [1/9]
# 2024-10-15 02:49:56,936 [MainThread] INFO UNetTrainer - Training iteration [3039/1800000]. Epoch [1/9]
# 2024-10-15 02:49:58,883 [MainThread] INFO UNetTrainer - Training iteration [3040/1800000]. Epoch [1/9]
# 2024-10-15 02:50:00,818 [MainThread] INFO UNetTrainer - Training iteration [3041/1800000]. Epoch [1/9]
# 2024-10-15 02:50:02,761 [MainThread] INFO UNetTrainer - Training iteration [3042/1800000]. Epoch [1/9]
# 2024-10-15 02:50:04,707 [MainThread] INFO UNetTrainer - Training iteration [3043/1800000]. Epoch [1/9]
# 2024-10-15 02:50:06,644 [MainThread] INFO UNetTrainer - Training iteration [3044/1800000]. Epoch [1/9]
# 2024-10-15 02:50:08,587 [MainThread] INFO UNetTrainer - Training iteration [3045/1800000]. Epoch [1/9]
# 2024-10-15 02:50:10,525 [MainThread] INFO UNetTrainer - Training iteration [3046/1800000]. Epoch [1/9]
# 2024-10-15 02:50:12,469 [MainThread] INFO UNetTrainer - Training iteration [3047/1800000]. Epoch [1/9]
# 2024-10-15 02:50:14,414 [MainThread] INFO UNetTrainer - Training iteration [3048/1800000]. Epoch [1/9]
# 2024-10-15 02:50:16,358 [MainThread] INFO UNetTrainer - Training iteration [3049/1800000]. Epoch [1/9]
# 2024-10-15 02:50:18,295 [MainThread] INFO UNetTrainer - Training iteration [3050/1800000]. Epoch [1/9]
# 2024-10-15 02:50:20,235 [MainThread] INFO UNetTrainer - Training iteration [3051/1800000]. Epoch [1/9]
# 2024-10-15 02:50:22,172 [MainThread] INFO UNetTrainer - Training iteration [3052/1800000]. Epoch [1/9]
# 2024-10-15 02:50:24,113 [MainThread] INFO UNetTrainer - Training iteration [3053/1800000]. Epoch [1/9]
# 2024-10-15 02:50:26,053 [MainThread] INFO UNetTrainer - Training iteration [3054/1800000]. Epoch [1/9]
# 2024-10-15 02:50:27,996 [MainThread] INFO UNetTrainer - Training iteration [3055/1800000]. Epoch [1/9]
# 2024-10-15 02:50:29,936 [MainThread] INFO UNetTrainer - Training iteration [3056/1800000]. Epoch [1/9]
# 2024-10-15 02:50:31,887 [MainThread] INFO UNetTrainer - Training iteration [3057/1800000]. Epoch [1/9]
# 2024-10-15 02:50:33,814 [MainThread] INFO UNetTrainer - Training iteration [3058/1800000]. Epoch [1/9]
# 2024-10-15 02:50:35,751 [MainThread] INFO UNetTrainer - Training iteration [3059/1800000]. Epoch [1/9]
# 2024-10-15 02:50:37,691 [MainThread] INFO UNetTrainer - Training iteration [3060/1800000]. Epoch [1/9]
# 2024-10-15 02:50:39,631 [MainThread] INFO UNetTrainer - Training iteration [3061/1800000]. Epoch [1/9]
# 2024-10-15 02:50:41,565 [MainThread] INFO UNetTrainer - Training iteration [3062/1800000]. Epoch [1/9]
# 2024-10-15 02:50:43,510 [MainThread] INFO UNetTrainer - Training iteration [3063/1800000]. Epoch [1/9]
# 2024-10-15 02:50:45,437 [MainThread] INFO UNetTrainer - Training iteration [3064/1800000]. Epoch [1/9]
# 2024-10-15 02:50:47,377 [MainThread] INFO UNetTrainer - Training iteration [3065/1800000]. Epoch [1/9]
# 2024-10-15 02:50:49,318 [MainThread] INFO UNetTrainer - Training iteration [3066/1800000]. Epoch [1/9]
# 2024-10-15 02:50:51,253 [MainThread] INFO UNetTrainer - Training iteration [3067/1800000]. Epoch [1/9]
# 2024-10-15 02:50:53,192 [MainThread] INFO UNetTrainer - Training iteration [3068/1800000]. Epoch [1/9]
# 2024-10-15 02:50:55,134 [MainThread] INFO UNetTrainer - Training iteration [3069/1800000]. Epoch [1/9]
# 2024-10-15 02:50:57,081 [MainThread] INFO UNetTrainer - Training iteration [3070/1800000]. Epoch [1/9]
# 2024-10-15 02:50:59,018 [MainThread] INFO UNetTrainer - Training iteration [3071/1800000]. Epoch [1/9]
# 2024-10-15 02:51:00,967 [MainThread] INFO UNetTrainer - Training iteration [3072/1800000]. Epoch [1/9]
# 2024-10-15 02:51:02,904 [MainThread] INFO UNetTrainer - Training iteration [3073/1800000]. Epoch [1/9]
# 2024-10-15 02:51:04,857 [MainThread] INFO UNetTrainer - Training iteration [3074/1800000]. Epoch [1/9]
# 2024-10-15 02:51:06,789 [MainThread] INFO UNetTrainer - Training iteration [3075/1800000]. Epoch [1/9]
# 2024-10-15 02:51:08,732 [MainThread] INFO UNetTrainer - Training iteration [3076/1800000]. Epoch [1/9]
# 2024-10-15 02:51:10,677 [MainThread] INFO UNetTrainer - Training iteration [3077/1800000]. Epoch [1/9]
# 2024-10-15 02:51:12,624 [MainThread] INFO UNetTrainer - Training iteration [3078/1800000]. Epoch [1/9]
# 2024-10-15 02:51:14,567 [MainThread] INFO UNetTrainer - Training iteration [3079/1800000]. Epoch [1/9]
# 2024-10-15 02:51:16,518 [MainThread] INFO UNetTrainer - Training iteration [3080/1800000]. Epoch [1/9]
# 2024-10-15 02:51:18,462 [MainThread] INFO UNetTrainer - Training iteration [3081/1800000]. Epoch [1/9]
# 2024-10-15 02:51:20,412 [MainThread] INFO UNetTrainer - Training iteration [3082/1800000]. Epoch [1/9]
# 2024-10-15 02:51:22,351 [MainThread] INFO UNetTrainer - Training iteration [3083/1800000]. Epoch [1/9]
# 2024-10-15 02:51:24,287 [MainThread] INFO UNetTrainer - Training iteration [3084/1800000]. Epoch [1/9]
# 2024-10-15 02:51:26,229 [MainThread] INFO UNetTrainer - Training iteration [3085/1800000]. Epoch [1/9]
# 2024-10-15 02:51:28,174 [MainThread] INFO UNetTrainer - Training iteration [3086/1800000]. Epoch [1/9]
# 2024-10-15 02:51:30,119 [MainThread] INFO UNetTrainer - Training iteration [3087/1800000]. Epoch [1/9]
# 2024-10-15 02:51:32,060 [MainThread] INFO UNetTrainer - Training iteration [3088/1800000]. Epoch [1/9]
# 2024-10-15 02:51:34,007 [MainThread] INFO UNetTrainer - Training iteration [3089/1800000]. Epoch [1/9]
# 2024-10-15 02:51:35,948 [MainThread] INFO UNetTrainer - Training iteration [3090/1800000]. Epoch [1/9]
# 2024-10-15 02:51:37,892 [MainThread] INFO UNetTrainer - Training iteration [3091/1800000]. Epoch [1/9]
# 2024-10-15 02:51:39,825 [MainThread] INFO UNetTrainer - Training iteration [3092/1800000]. Epoch [1/9]
# 2024-10-15 02:51:41,765 [MainThread] INFO UNetTrainer - Training iteration [3093/1800000]. Epoch [1/9]
# 2024-10-15 02:51:43,707 [MainThread] INFO UNetTrainer - Training iteration [3094/1800000]. Epoch [1/9]
# 2024-10-15 02:51:45,649 [MainThread] INFO UNetTrainer - Training iteration [3095/1800000]. Epoch [1/9]
# 2024-10-15 02:51:47,592 [MainThread] INFO UNetTrainer - Training iteration [3096/1800000]. Epoch [1/9]
# 2024-10-15 02:51:49,540 [MainThread] INFO UNetTrainer - Training iteration [3097/1800000]. Epoch [1/9]
# 2024-10-15 02:51:51,479 [MainThread] INFO UNetTrainer - Training iteration [3098/1800000]. Epoch [1/9]
# 2024-10-15 02:51:53,419 [MainThread] INFO UNetTrainer - Training iteration [3099/1800000]. Epoch [1/9]
# 2024-10-15 02:51:55,353 [MainThread] INFO UNetTrainer - Training iteration [3100/1800000]. Epoch [1/9]
# 2024-10-15 02:51:57,296 [MainThread] INFO UNetTrainer - Training iteration [3101/1800000]. Epoch [1/9]
# 2024-10-15 02:51:59,234 [MainThread] INFO UNetTrainer - Training iteration [3102/1800000]. Epoch [1/9]
# 2024-10-15 02:52:01,179 [MainThread] INFO UNetTrainer - Training iteration [3103/1800000]. Epoch [1/9]
# 2024-10-15 02:52:03,125 [MainThread] INFO UNetTrainer - Training iteration [3104/1800000]. Epoch [1/9]
# 2024-10-15 02:52:05,080 [MainThread] INFO UNetTrainer - Training iteration [3105/1800000]. Epoch [1/9]
# 2024-10-15 02:52:07,015 [MainThread] INFO UNetTrainer - Training iteration [3106/1800000]. Epoch [1/9]
# 2024-10-15 02:52:08,964 [MainThread] INFO UNetTrainer - Training iteration [3107/1800000]. Epoch [1/9]
# 2024-10-15 02:52:10,901 [MainThread] INFO UNetTrainer - Training iteration [3108/1800000]. Epoch [1/9]
# 2024-10-15 02:52:12,855 [MainThread] INFO UNetTrainer - Training iteration [3109/1800000]. Epoch [1/9]
# 2024-10-15 02:52:14,809 [MainThread] INFO UNetTrainer - Training iteration [3110/1800000]. Epoch [1/9]
# 2024-10-15 02:52:16,746 [MainThread] INFO UNetTrainer - Training iteration [3111/1800000]. Epoch [1/9]
# 2024-10-15 02:52:18,694 [MainThread] INFO UNetTrainer - Training iteration [3112/1800000]. Epoch [1/9]
# 2024-10-15 02:52:20,651 [MainThread] INFO UNetTrainer - Training iteration [3113/1800000]. Epoch [1/9]
# 2024-10-15 02:52:22,602 [MainThread] INFO UNetTrainer - Training iteration [3114/1800000]. Epoch [1/9]
# 2024-10-15 02:52:24,554 [MainThread] INFO UNetTrainer - Training iteration [3115/1800000]. Epoch [1/9]
# 2024-10-15 02:52:26,504 [MainThread] INFO UNetTrainer - Training iteration [3116/1800000]. Epoch [1/9]
# 2024-10-15 02:52:28,453 [MainThread] INFO UNetTrainer - Training iteration [3117/1800000]. Epoch [1/9]
# 2024-10-15 02:52:30,404 [MainThread] INFO UNetTrainer - Training iteration [3118/1800000]. Epoch [1/9]
# 2024-10-15 02:52:32,356 [MainThread] INFO UNetTrainer - Training iteration [3119/1800000]. Epoch [1/9]
# 2024-10-15 02:52:34,306 [MainThread] INFO UNetTrainer - Training iteration [3120/1800000]. Epoch [1/9]
# 2024-10-15 02:52:36,263 [MainThread] INFO UNetTrainer - Training iteration [3121/1800000]. Epoch [1/9]
# 2024-10-15 02:52:38,211 [MainThread] INFO UNetTrainer - Training iteration [3122/1800000]. Epoch [1/9]
# 2024-10-15 02:52:40,168 [MainThread] INFO UNetTrainer - Training iteration [3123/1800000]. Epoch [1/9]
# 2024-10-15 02:52:42,118 [MainThread] INFO UNetTrainer - Training iteration [3124/1800000]. Epoch [1/9]
# 2024-10-15 02:52:44,056 [MainThread] INFO UNetTrainer - Training iteration [3125/1800000]. Epoch [1/9]
# 2024-10-15 02:52:46,005 [MainThread] INFO UNetTrainer - Training iteration [3126/1800000]. Epoch [1/9]
# 2024-10-15 02:52:47,952 [MainThread] INFO UNetTrainer - Training iteration [3127/1800000]. Epoch [1/9]
# 2024-10-15 02:52:49,900 [MainThread] INFO UNetTrainer - Training iteration [3128/1800000]. Epoch [1/9]
# 2024-10-15 02:52:51,849 [MainThread] INFO UNetTrainer - Training iteration [3129/1800000]. Epoch [1/9]
# 2024-10-15 02:52:53,798 [MainThread] INFO UNetTrainer - Training iteration [3130/1800000]. Epoch [1/9]
# 2024-10-15 02:52:55,758 [MainThread] INFO UNetTrainer - Training iteration [3131/1800000]. Epoch [1/9]
# 2024-10-15 02:52:57,699 [MainThread] INFO UNetTrainer - Training iteration [3132/1800000]. Epoch [1/9]
# 2024-10-15 02:52:59,646 [MainThread] INFO UNetTrainer - Training iteration [3133/1800000]. Epoch [1/9]
# 2024-10-15 02:53:01,592 [MainThread] INFO UNetTrainer - Training iteration [3134/1800000]. Epoch [1/9]
# 2024-10-15 02:53:03,540 [MainThread] INFO UNetTrainer - Training iteration [3135/1800000]. Epoch [1/9]
# 2024-10-15 02:53:05,484 [MainThread] INFO UNetTrainer - Training iteration [3136/1800000]. Epoch [1/9]
# 2024-10-15 02:53:07,431 [MainThread] INFO UNetTrainer - Training iteration [3137/1800000]. Epoch [1/9]
# 2024-10-15 02:53:09,374 [MainThread] INFO UNetTrainer - Training iteration [3138/1800000]. Epoch [1/9]
# 2024-10-15 02:53:11,329 [MainThread] INFO UNetTrainer - Training iteration [3139/1800000]. Epoch [1/9]
# 2024-10-15 02:53:13,279 [MainThread] INFO UNetTrainer - Training iteration [3140/1800000]. Epoch [1/9]
# 2024-10-15 02:53:15,217 [MainThread] INFO UNetTrainer - Training iteration [3141/1800000]. Epoch [1/9]
# 2024-10-15 02:53:17,168 [MainThread] INFO UNetTrainer - Training iteration [3142/1800000]. Epoch [1/9]
# 2024-10-15 02:53:19,118 [MainThread] INFO UNetTrainer - Training iteration [3143/1800000]. Epoch [1/9]
# 2024-10-15 02:53:21,066 [MainThread] INFO UNetTrainer - Training iteration [3144/1800000]. Epoch [1/9]
# 2024-10-15 02:53:23,011 [MainThread] INFO UNetTrainer - Training iteration [3145/1800000]. Epoch [1/9]
# 2024-10-15 02:53:24,962 [MainThread] INFO UNetTrainer - Training iteration [3146/1800000]. Epoch [1/9]
# 2024-10-15 02:53:26,913 [MainThread] INFO UNetTrainer - Training iteration [3147/1800000]. Epoch [1/9]
# 2024-10-15 02:53:28,861 [MainThread] INFO UNetTrainer - Training iteration [3148/1800000]. Epoch [1/9]
# 2024-10-15 02:53:30,811 [MainThread] INFO UNetTrainer - Training iteration [3149/1800000]. Epoch [1/9]
# 2024-10-15 02:53:32,757 [MainThread] INFO UNetTrainer - Training iteration [3150/1800000]. Epoch [1/9]
# 2024-10-15 02:53:34,712 [MainThread] INFO UNetTrainer - Training iteration [3151/1800000]. Epoch [1/9]
# 2024-10-15 02:53:36,662 [MainThread] INFO UNetTrainer - Training iteration [3152/1800000]. Epoch [1/9]
# 2024-10-15 02:53:38,616 [MainThread] INFO UNetTrainer - Training iteration [3153/1800000]. Epoch [1/9]
# 2024-10-15 02:53:40,563 [MainThread] INFO UNetTrainer - Training iteration [3154/1800000]. Epoch [1/9]
# 2024-10-15 02:53:42,515 [MainThread] INFO UNetTrainer - Training iteration [3155/1800000]. Epoch [1/9]
# 2024-10-15 02:53:44,468 [MainThread] INFO UNetTrainer - Training iteration [3156/1800000]. Epoch [1/9]
# 2024-10-15 02:53:46,418 [MainThread] INFO UNetTrainer - Training iteration [3157/1800000]. Epoch [1/9]
# 2024-10-15 02:53:48,369 [MainThread] INFO UNetTrainer - Training iteration [3158/1800000]. Epoch [1/9]
# Traceback (most recent call last):
#   File "/usr/local/bin/train3dunet", line 33, in <module>
#     sys.exit(load_entry_point('pytorch3dunet==1.8.7', 'console_scripts', 'train3dunet')())
#   File "/usr/local/lib/python3.10/dist-packages/pytorch3dunet-1.8.7-py3.10.egg/pytorch3dunet/train.py", line 31, in main
#   File "/usr/local/lib/python3.10/dist-packages/pytorch3dunet-1.8.7-py3.10.egg/pytorch3dunet/unet3d/trainer.py", line 151, in fit
#   File "/usr/local/lib/python3.10/dist-packages/pytorch3dunet-1.8.7-py3.10.egg/pytorch3dunet/unet3d/trainer.py", line 180, in train
# KeyboardInterrupt

# %%
test_config_yaml ={
    "model_path": model_path,
    "model": {
        "name": model_name,
        "in_channels": in_channels,
        "out_channels": out_channels,
        "layer_order": layer_order,
        "f_maps": f_maps,
        "num_groups": num_groups,
        "final_sigmoid": final_sigmoid,
        "is_segmentation": is_segmentation
    },
    "predictor": {
        "name": predictor_name
    },
    "loaders": {
        "batch_size": batch_size,
        "raw_internal_path": raw_internal_path,
        "num_workers": num_workers,
        "test": {
            "file_paths": [
                file_paths_test
            ],
            "slice_builder": {
                "name": slice_builder_name_predict,
                "patch_shape": patch_shape,
                "stride_shape": patch_shape,
                "halo_shape": halo_shape
            },
            "transformer": {
                "raw": [
                    {
                        "name": name_transformer
                    },
                    {
                        "name": ToTensor_name,
                        "expand_dims": expand_dims_true
                    }
                ]
            }
        }
    }
}

with open(config_folder+'predict.yaml', 'w') as yaml_file:
    yaml.dump(test_config_yaml, yaml_file, default_flow_style=False, sort_keys=False)

# %%
print(yaml.dump(test_config_yaml, default_flow_style=False, sort_keys=False))
# Out:
# model_path: /content/drive/MyDrive/3D_UNET/checkpoint_dir/best_checkpoint.pytorch
# model:
#   name: UNet3D
#   in_channels: 1
#   out_channels: 1
#   layer_order: gcr
#   f_maps:
#   - 32
#   - 64
#   - 128
#   - 256
#   num_groups: 8
#   final_sigmoid: true
#   is_segmentation: true
# predictor:
#   name: StandardPredictor
# loaders:
#   batch_size: 3
#   raw_internal_path: raw
#   num_workers: 2
#   test:
#     file_paths:
#     - /content/drive/MyDrive/3D_UNET/training_visit_3_transfer/test/
#     slice_builder:
#       name: SliceBuilder
#       patch_shape: &id001
#       - 40
#       - 170
#       - 170
#       stride_shape: *id001
#       halo_shape:
#       - 16
#       - 32
#       - 32
#     transformer:
#       raw:
#       - name: Standardize
#       - name: ToTensor
#         expand_dims: true

# %%
# !predict3dunet --config /content/drive/MyDrive/3D_UNET/config_files/predict.yaml
# Out:
# 2024-10-15 02:53:53,875 [MainThread] INFO UNet3DPredict - Loading model from /content/drive/MyDrive/3D_UNET/checkpoint_dir/best_checkpoint.pytorch...
# /usr/local/lib/python3.10/dist-packages/pytorch3dunet-1.8.7-py3.10.egg/pytorch3dunet/unet3d/utils.py:51: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# 2024-10-15 02:53:54,570 [MainThread] INFO Dataset - Creating test set loaders...
# 2024-10-15 02:53:54,570 [MainThread] WARNING Dataset - Cannot find dataset class in the config. Using default 'StandardHDF5Dataset'.
# 2024-10-15 02:53:54,575 [MainThread] INFO HDF5Dataset - Loading test set from: /content/drive/MyDrive/3D_UNET/training_visit_3_transfer/test/recon_sub__078_corn_pvc_2days_R3_wb_1x_stitch.tif_002.h5...
# 2024-10-15 02:53:55,128 [MainThread] INFO Dataset - Slice builder config: {'name': 'SliceBuilder', 'patch_shape': [40, 170, 170], 'stride_shape': [40, 170, 170], 'halo_shape': [16, 32, 32]}
# 2024-10-15 02:53:55,150 [MainThread] INFO HDF5Dataset - Number of patches: 208
# 2024-10-15 02:53:55,150 [MainThread] INFO HDF5Dataset - Loading test set from: /content/drive/MyDrive/3D_UNET/training_visit_3_transfer/test/recon_sub__103_wheat_pvc_4days_R3_wb_1x_stitch.tif_014.h5...
# 2024-10-15 02:53:55,903 [MainThread] INFO Dataset - Slice builder config: {'name': 'SliceBuilder', 'patch_shape': [40, 170, 170], 'stride_shape': [40, 170, 170], 'halo_shape': [16, 32, 32]}
# 2024-10-15 02:53:55,909 [MainThread] INFO HDF5Dataset - Number of patches: 208
# 2024-10-15 02:53:55,909 [MainThread] INFO HDF5Dataset - Loading test set from: /content/drive/MyDrive/3D_UNET/training_visit_3_transfer/test/recon_sub__078_corn_pvc_2days_R3_wb_1x_stitch.tif_002_predictions.h5...
# 2024-10-15 02:53:56,672 [MainThread] ERROR HDF5Dataset - Skipping test set: /content/drive/MyDrive/3D_UNET/training_visit_3_transfer/test/recon_sub__078_corn_pvc_2days_R3_wb_1x_stitch.tif_002_predictions.h5
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pytorch3dunet-1.8.7-py3.10.egg/pytorch3dunet/datasets/hdf5.py", line 199, in create_datasets
#     dataset = cls(file_path=file_path,
#   File "/usr/local/lib/python3.10/dist-packages/pytorch3dunet-1.8.7-py3.10.egg/pytorch3dunet/datasets/hdf5.py", line 222, in __init__
#     super().__init__(file_path=file_path, phase=phase, slice_builder_config=slice_builder_config,
#   File "/usr/local/lib/python3.10/dist-packages/pytorch3dunet-1.8.7-py3.10.egg/pytorch3dunet/datasets/hdf5.py", line 96, in __init__
#     raw = f[raw_internal_path]
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "/usr/local/lib/python3.10/dist-packages/h5py/_hl/group.py", line 357, in __getitem__
#     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py/h5o.pyx", line 241, in h5py.h5o.open
# KeyError: "Unable to synchronously open object (object 'raw' doesn't exist)"
# 2024-10-15 02:53:56,673 [MainThread] INFO HDF5Dataset - Loading test set from: /content/drive/MyDrive/3D_UNET/training_visit_3_transfer/test/recon_sub__103_wheat_pvc_4days_R3_wb_1x_stitch.tif_014_predictions.h5...
# 2024-10-15 02:53:57,384 [MainThread] ERROR HDF5Dataset - Skipping test set: /content/drive/MyDrive/3D_UNET/training_visit_3_transfer/test/recon_sub__103_wheat_pvc_4days_R3_wb_1x_stitch.tif_014_predictions.h5
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pytorch3dunet-1.8.7-py3.10.egg/pytorch3dunet/datasets/hdf5.py", line 199, in create_datasets
#     dataset = cls(file_path=file_path,
#   File "/usr/local/lib/python3.10/dist-packages/pytorch3dunet-1.8.7-py3.10.egg/pytorch3dunet/datasets/hdf5.py", line 222, in __init__
#     super().__init__(file_path=file_path, phase=phase, slice_builder_config=slice_builder_config,
#   File "/usr/local/lib/python3.10/dist-packages/pytorch3dunet-1.8.7-py3.10.egg/pytorch3dunet/datasets/hdf5.py", line 96, in __init__
#     raw = f[raw_internal_path]
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "/usr/local/lib/python3.10/dist-packages/h5py/_hl/group.py", line 357, in __getitem__
#     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py/h5o.pyx", line 241, in h5py.h5o.open
# KeyError: "Unable to synchronously open object (object 'raw' doesn't exist)"
# 2024-10-15 02:53:57,384 [MainThread] INFO Dataset - Number of workers for the dataloader: 2
# 2024-10-15 02:53:57,385 [MainThread] INFO Dataset - Batch size for dataloader: 3
# 2024-10-15 02:53:57,385 [MainThread] INFO Dataset - Loading test set from: /content/drive/MyDrive/3D_UNET/training_visit_3_transfer/test/recon_sub__078_corn_pvc_2days_R3_wb_1x_stitch.tif_002.h5...
# 2024-10-15 02:53:57,385 [MainThread] INFO UNetPredictor - Processing '/content/drive/MyDrive/3D_UNET/training_visit_3_transfer/test/recon_sub__078_corn_pvc_2days_R3_wb_1x_stitch.tif_002.h5'...
# 2024-10-15 02:53:57,385 [MainThread] INFO UNetPredictor - Running inference on 70 batches
# 2024-10-15 02:54:05,001 [MainThread] INFO UNetPredictor - Allocating prediction and normalization arrays...
# 100% 70/70 [02:33<00:00,  2.20s/it]
# 2024-10-15 02:56:38,785 [MainThread] INFO UNetPredictor - Finished inference in 161.40 seconds
# 2024-10-15 02:56:38,785 [MainThread] INFO UNetPredictor - Saving probability maps to: /content/drive/MyDrive/3D_UNET/training_visit_3_transfer/test/recon_sub__078_corn_pvc_2days_R3_wb_1x_stitch.tif_002_predictions.h5
# 2024-10-15 02:57:05,605 [MainThread] INFO Dataset - Loading test set from: /content/drive/MyDrive/3D_UNET/training_visit_3_transfer/test/recon_sub__103_wheat_pvc_4days_R3_wb_1x_stitch.tif_014.h5...
# 2024-10-15 02:57:05,605 [MainThread] INFO UNetPredictor - Processing '/content/drive/MyDrive/3D_UNET/training_visit_3_transfer/test/recon_sub__103_wheat_pvc_4days_R3_wb_1x_stitch.tif_014.h5'...
# 2024-10-15 02:57:05,605 [MainThread] INFO UNetPredictor - Running inference on 70 batches
# 2024-10-15 02:57:11,306 [MainThread] INFO UNetPredictor - Allocating prediction and normalization arrays...
#  46% 32/70 [01:12<01:19,  2.10s/it]

# %%
import glob
import numpy as np
raw_data_path= file_paths_test
raw_file_names = [os.path.basename(x) for x in glob.glob(raw_data_path+"*.h5")]
raw_file_names = [e for e in raw_file_names if "predictions" in e ]
#################################
file_paths_processed= "/content/drive/MyDrive/3D_UNET/training_visit_3_transfer/processed/"
#########################
raw_file_names

# %%
UNIQUE_ID =np.unique(raw_file_names)
len(UNIQUE_ID)

# %%
import h5py
import cv2
import skimage
from skimage.filters import threshold_otsu, threshold_yen
from skimage.measure import label
from skimage.morphology import remove_small_objects
from vedo import *
import pyvista as pv
for i in UNIQUE_ID:
    print(i)
    hf=h5py.File(raw_data_path+i)
    hf.keys()
    dataset_IMGs= hf['predictions']
    image=dataset_IMGs[:]
    image=image[0,:,:,:]
    #image=zoom(image, (scale_factor,scale_factor, scale_factor), order=1)
    image = cv2.normalize(image, None, 0, 255, cv2.NORM_MINMAX, dtype=cv2.CV_8U)
    thresh = threshold_yen(image)-45
    #thresh=20
    print (thresh)
    binary = image > thresh
    #binary=zoom(binary, (scale_factor,scale_factor, scale_factor), order=0)
    root_sml=label(binary)
    min_size_coef=2500 #trial and error really
    root_sml_obj = remove_small_objects(root_sml, min_size=min_size_coef, connectivity=2)
    root_sml_obj = (root_sml_obj != 0).astype(bool)

    root_VOL = Volume(root_sml_obj, spacing=((1),(1),(1)))
    root_ISO = root_VOL.isosurface(1)
    root_ISO.write(file_paths_processed+i+"__root.stl")
    skimage.io.imsave(file_paths_processed+i+"_processed.tif", root_sml_obj, check_contrast=False)

# %% [markdown]
# Now, to sanity check lets create a 3D model of the root system we just segmented using 3D-Unet

# %%
import open3d as o3d
import plotly.graph_objects as go
model_to_test="recon_sub__103_wheat_pvc_4days_R3_wb_1x_stitch.tif_014_predictions.h5__root.stl"
mesh = o3d.io.read_triangle_mesh(file_paths_processed+model_to_test)
if not mesh.has_vertex_normals(): mesh.compute_vertex_normals()
if not mesh.has_triangle_normals(): mesh.compute_triangle_normals()
triangles = np.asarray(mesh.triangles)
vertices = np.asarray(mesh.vertices)
colors = None

colors = (1.0, 0.0, 0.0)

fig = go.Figure(
    data=[
        go.Mesh3d(
            x=vertices[:,0],
            y=vertices[:,1],
            z=vertices[:,2],
            i=triangles[:,0],
            j=triangles[:,1],
            k=triangles[:,2],
            facecolor=colors,
            opacity=0.50)
    ],
    layout=dict(
        scene=dict(
            xaxis=dict(visible=False),
            yaxis=dict(visible=False),
            zaxis=dict(visible=False)
        )
    )
)
fig.show()
